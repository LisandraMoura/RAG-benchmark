# %% [markdown]
# # RAG

# %%
## setup
# !pip install anthropic
# !pip install voyageai
# !pip install pandas
# !pip install numpy
# !pip install matplotlib
# !pip install seaborn
# !pip install -U scikit-learn
# Out:
# Requirement already satisfied: anthropic in /home/lisamenezes/anaconda3/envs/basic/lib/python3.9/site-packages (0.39.0)
# Requirement already satisfied: anyio<5,>=3.5.0 in /home/lisamenezes/anaconda3/envs/basic/lib/python3.9/site-packages (from anthropic) (3.7.1)
# Requirement already satisfied: distro<2,>=1.7.0 in /home/lisamenezes/anaconda3/envs/basic/lib/python3.9/site-packages (from anthropic) (1.9.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in /home/lisamenezes/anaconda3/envs/basic/lib/python3.9/site-packages (from anthropic) (0.27.2)
# Requirement already satisfied: jiter<1,>=0.4.0 in /home/lisamenezes/anaconda3/envs/basic/lib/python3.9/site-packages (from anthropic) (0.6.1)
# Requirement already satisfied: pydantic<3,>=1.9.0 in /home/lisamenezes/anaconda3/envs/basic/lib/python3.9/site-packages (from anthropic) (2.9.2)
# Requirement already satisfied: sniffio in /home/lisamenezes/anaconda3/envs/basic/lib/python3.9/site-packages (from anthropic) (1.3.1)
# Requirement already satisfied: typing-extensions<5,>=4.7 in /home/lisamenezes/anaconda3/envs/basic/lib/python3.9/site-packages (from anthropic) (4.12.2)
# Requirement already satisfied: idna>=2.8 in /home/lisamenezes/anaconda3/envs/basic/lib/python3.9/site-packages (from anyio<5,>=3.5.0->anthropic) (3.8)
# Requirement already satisfied: exceptiongroup in /home/lisamenezes/anaconda3/envs/basic/lib/python3.9/site-packages (from anyio<5,>=3.5.0->anthropic) (1.2.2)
# Requirement already satisfied: certifi in /home/lisamenezes/anaconda3/envs/basic/lib/python3.9/site-packages (from httpx<1,>=0.23.0->anthropic) (2024.8.30)
# Requirement already satisfied: httpcore==1.* in /home/lisamenezes/anaconda3/envs/basic/lib/python3.9/site-packages (from httpx<1,>=0.23.0->anthropic) (1.0.5)
# Requirement already satisfied: h11<0.15,>=0.13 in /home/lisamenezes/anaconda3/envs/basic/lib/python3.9/site-packages (from httpcore==1.*->httpx<1,>=0.23.0->anthropic) (0.14.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /home/lisamenezes/anaconda3/envs/basic/lib/python3.9/site-packages (from pydantic<3,>=1.9.0->anthropic) (0.7.0)
# Requirement already satisfied: pydantic-core==2.23.4 in /home/lisamenezes/anaconda3/envs/basic/lib/python3.9/site-packages (from pydantic<3,>=1.9.0->anthropic) (2.23.4)
# Requirement already satisfied: voyageai in /home/lisamenezes/anaconda3/envs/basic/lib/python3.9/site-packages (0.3.1)
# Requirement already satisfied: aiohttp in /home/lisamenezes/anaconda3/envs/basic/lib/python3.9/site-packages (from voyageai) (3.10.5)
# Requirement already satisfied: aiolimiter in /home/lisamenezes/anaconda3/envs/basic/lib/python3.9/site-packages (from voyageai) (1.1.0)
# Requirement already satisfied: numpy in /home/lisamenezes/anaconda3/envs/basic/lib/python3.9/site-packages (from voyageai) (1.26.4)
# Requirement already satisfied: pillow in /home/lisamenezes/anaconda3/envs/basic/lib/python3.9/site-packages (from voyageai) (10.4.0)
# Requirement already satisfied: pydantic>=1.10.8 in /home/lisamenezes/anaconda3/envs/basic/lib/python3.9/site-packages (from voyageai) (2.9.2)
# Requirement already satisfied: requests in /home/lisamenezes/anaconda3/envs/basic/lib/python3.9/site-packages (from voyageai) (2.32.3)
# Requirement already satisfied: tenacity in /home/lisamenezes/anaconda3/envs/basic/lib/python3.9/site-packages (from voyageai) (8.5.0)
# Requirement already satisfied: tokenizers>=0.14.0 in /home/lisamenezes/anaconda3/envs/basic/lib/python3.9/site-packages (from voyageai) (0.20.3)
# Requirement already satisfied: annotated-types>=0.6.0 in /home/lisamenezes/anaconda3/envs/basic/lib/python3.9/site-packages (from pydantic>=1.10.8->voyageai) (0.7.0)
# Requirement already satisfied: pydantic-core==2.23.4 in /home/lisamenezes/anaconda3/envs/basic/lib/python3.9/site-packages (from pydantic>=1.10.8->voyageai) (2.23.4)
# Requirement already satisfied: typing-extensions>=4.6.1 in /home/lisamenezes/anaconda3/envs/basic/lib/python3.9/site-packages (from pydantic>=1.10.8->voyageai) (4.12.2)
# Requirement already satisfied: huggingface-hub<1.0,>=0.16.4 in /home/lisamenezes/anaconda3/envs/basic/lib/python3.9/site-packages (from tokenizers>=0.14.0->voyageai) (0.24.6)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in /home/lisamenezes/anaconda3/envs/basic/lib/python3.9/site-packages (from aiohttp->voyageai) (2.4.0)
# Requirement already satisfied: aiosignal>=1.1.2 in /home/lisamenezes/anaconda3/envs/basic/lib/python3.9/site-packages (from aiohttp->voyageai) (1.3.1)
# Requirement already satisfied: attrs>=17.3.0 in /home/lisamenezes/anaconda3/envs/basic/lib/python3.9/site-packages (from aiohttp->voyageai) (24.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /home/lisamenezes/anaconda3/envs/basic/lib/python3.9/site-packages (from aiohttp->voyageai) (1.4.1)
# Requirement already satisfied: multidict<7.0,>=4.5 in /home/lisamenezes/anaconda3/envs/basic/lib/python3.9/site-packages (from aiohttp->voyageai) (6.0.5)
# Requirement already satisfied: yarl<2.0,>=1.0 in /home/lisamenezes/anaconda3/envs/basic/lib/python3.9/site-packages (from aiohttp->voyageai) (1.9.11)
# Requirement already satisfied: async-timeout<5.0,>=4.0 in /home/lisamenezes/anaconda3/envs/basic/lib/python3.9/site-packages (from aiohttp->voyageai) (4.0.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /home/lisamenezes/anaconda3/envs/basic/lib/python3.9/site-packages (from requests->voyageai) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /home/lisamenezes/anaconda3/envs/basic/lib/python3.9/site-packages (from requests->voyageai) (3.8)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/lisamenezes/anaconda3/envs/basic/lib/python3.9/site-packages (from requests->voyageai) (1.26.20)
# Requirement already satisfied: certifi>=2017.4.17 in /home/lisamenezes/anaconda3/envs/basic/lib/python3.9/site-packages (from requests->voyageai) (2024.8.30)
# Requirement already satisfied: filelock in /home/lisamenezes/anaconda3/envs/basic/lib/python3.9/site-packages (from huggingface-hub<1.0,>=0.16.4->tokenizers>=0.14.0->voyageai) (3.15.4)
# Requirement already satisfied: fsspec>=2023.5.0 in /home/lisamenezes/anaconda3/envs/basic/lib/python3.9/site-packages (from huggingface-hub<1.0,>=0.16.4->tokenizers>=0.14.0->voyageai) (2024.6.1)
# Requirement already satisfied: packaging>=20.9 in /home/lisamenezes/anaconda3/envs/basic/lib/python3.9/site-packages (from huggingface-hub<1.0,>=0.16.4->tokenizers>=0.14.0->voyageai) (23.2)
# Requirement already satisfied: pyyaml>=5.1 in /home/lisamenezes/anaconda3/envs/basic/lib/python3.9/site-packages (from huggingface-hub<1.0,>=0.16.4->tokenizers>=0.14.0->voyageai) (6.0.2)
# Requirement already satisfied: tqdm>=4.42.1 in /home/lisamenezes/anaconda3/envs/basic/lib/python3.9/site-packages (from huggingface-hub<1.0,>=0.16.4->tokenizers>=0.14.0->voyageai) (4.66.5)
# Requirement already satisfied: pandas in /home/lisamenezes/anaconda3/envs/basic/lib/python3.9/site-packages (2.2.2)
# Requirement already satisfied: numpy>=1.22.4 in /home/lisamenezes/anaconda3/envs/basic/lib/python3.9/site-packages (from pandas) (1.26.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in /home/lisamenezes/anaconda3/envs/basic/lib/python3.9/site-packages (from pandas) (2.9.0)
# Requirement already satisfied: pytz>=2020.1 in /home/lisamenezes/anaconda3/envs/basic/lib/python3.9/site-packages (from pandas) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in /home/lisamenezes/anaconda3/envs/basic/lib/python3.9/site-packages (from pandas) (2024.1)
# Requirement already satisfied: six>=1.5 in /home/lisamenezes/anaconda3/envs/basic/lib/python3.9/site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)
# Requirement already satisfied: numpy in /home/lisamenezes/anaconda3/envs/basic/lib/python3.9/site-packages (1.26.4)
# Requirement already satisfied: matplotlib in /home/lisamenezes/anaconda3/envs/basic/lib/python3.9/site-packages (3.9.2)
# Requirement already satisfied: contourpy>=1.0.1 in /home/lisamenezes/anaconda3/envs/basic/lib/python3.9/site-packages (from matplotlib) (1.3.0)
# Requirement already satisfied: cycler>=0.10 in /home/lisamenezes/anaconda3/envs/basic/lib/python3.9/site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /home/lisamenezes/anaconda3/envs/basic/lib/python3.9/site-packages (from matplotlib) (4.53.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /home/lisamenezes/anaconda3/envs/basic/lib/python3.9/site-packages (from matplotlib) (1.4.7)
# Requirement already satisfied: numpy>=1.23 in /home/lisamenezes/anaconda3/envs/basic/lib/python3.9/site-packages (from matplotlib) (1.26.4)
# Requirement already satisfied: packaging>=20.0 in /home/lisamenezes/anaconda3/envs/basic/lib/python3.9/site-packages (from matplotlib) (23.2)
# Requirement already satisfied: pillow>=8 in /home/lisamenezes/anaconda3/envs/basic/lib/python3.9/site-packages (from matplotlib) (10.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /home/lisamenezes/anaconda3/envs/basic/lib/python3.9/site-packages (from matplotlib) (3.1.4)
# Requirement already satisfied: python-dateutil>=2.7 in /home/lisamenezes/anaconda3/envs/basic/lib/python3.9/site-packages (from matplotlib) (2.9.0)
# Requirement already satisfied: importlib-resources>=3.2.0 in /home/lisamenezes/anaconda3/envs/basic/lib/python3.9/site-packages (from matplotlib) (6.4.4)
# Requirement already satisfied: zipp>=3.1.0 in /home/lisamenezes/anaconda3/envs/basic/lib/python3.9/site-packages (from importlib-resources>=3.2.0->matplotlib) (3.20.1)
# Requirement already satisfied: six>=1.5 in /home/lisamenezes/anaconda3/envs/basic/lib/python3.9/site-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)
# Requirement already satisfied: seaborn in /home/lisamenezes/anaconda3/envs/basic/lib/python3.9/site-packages (0.13.2)
# Requirement already satisfied: numpy!=1.24.0,>=1.20 in /home/lisamenezes/anaconda3/envs/basic/lib/python3.9/site-packages (from seaborn) (1.26.4)
# Requirement already satisfied: pandas>=1.2 in /home/lisamenezes/anaconda3/envs/basic/lib/python3.9/site-packages (from seaborn) (2.2.2)
# Requirement already satisfied: matplotlib!=3.6.1,>=3.4 in /home/lisamenezes/anaconda3/envs/basic/lib/python3.9/site-packages (from seaborn) (3.9.2)
# Requirement already satisfied: contourpy>=1.0.1 in /home/lisamenezes/anaconda3/envs/basic/lib/python3.9/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.3.0)
# Requirement already satisfied: cycler>=0.10 in /home/lisamenezes/anaconda3/envs/basic/lib/python3.9/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /home/lisamenezes/anaconda3/envs/basic/lib/python3.9/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (4.53.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /home/lisamenezes/anaconda3/envs/basic/lib/python3.9/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.4.7)
# Requirement already satisfied: packaging>=20.0 in /home/lisamenezes/anaconda3/envs/basic/lib/python3.9/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (23.2)
# Requirement already satisfied: pillow>=8 in /home/lisamenezes/anaconda3/envs/basic/lib/python3.9/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (10.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /home/lisamenezes/anaconda3/envs/basic/lib/python3.9/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (3.1.4)
# Requirement already satisfied: python-dateutil>=2.7 in /home/lisamenezes/anaconda3/envs/basic/lib/python3.9/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (2.9.0)
# Requirement already satisfied: importlib-resources>=3.2.0 in /home/lisamenezes/anaconda3/envs/basic/lib/python3.9/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (6.4.4)
# Requirement already satisfied: pytz>=2020.1 in /home/lisamenezes/anaconda3/envs/basic/lib/python3.9/site-packages (from pandas>=1.2->seaborn) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in /home/lisamenezes/anaconda3/envs/basic/lib/python3.9/site-packages (from pandas>=1.2->seaborn) (2024.1)
# Requirement already satisfied: zipp>=3.1.0 in /home/lisamenezes/anaconda3/envs/basic/lib/python3.9/site-packages (from importlib-resources>=3.2.0->matplotlib!=3.6.1,>=3.4->seaborn) (3.20.1)
# Requirement already satisfied: six>=1.5 in /home/lisamenezes/anaconda3/envs/basic/lib/python3.9/site-packages (from python-dateutil>=2.7->matplotlib!=3.6.1,>=3.4->seaborn) (1.16.0)
# Requirement already satisfied: scikit-learn in /home/lisamenezes/anaconda3/envs/basic/lib/python3.9/site-packages (1.5.2)
# Requirement already satisfied: numpy>=1.19.5 in /home/lisamenezes/anaconda3/envs/basic/lib/python3.9/site-packages (from scikit-learn) (1.26.4)
# Requirement already satisfied: scipy>=1.6.0 in /home/lisamenezes/anaconda3/envs/basic/lib/python3.9/site-packages (from scikit-learn) (1.13.1)
# Requirement already satisfied: joblib>=1.2.0 in /home/lisamenezes/anaconda3/envs/basic/lib/python3.9/site-packages (from scikit-learn) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /home/lisamenezes/anaconda3/envs/basic/lib/python3.9/site-packages (from scikit-learn) (3.5.0)

# %%
import os
import openai
from dotenv import load_dotenv

load_dotenv()
os.environ['VOYAGE_API_KEY'] = ('VOYAGE_API_KEY')
openai.api_key = os.getenv("OPENAI_API_KEY")

# %% [markdown]
# # Initialize a Vector DB Class

# %%
import os
import pickle
import json
import numpy as np
import openai

class VectorDB:
    def __init__(self, name, api_key=None):
        self.name = name
        self.embeddings = []
        self.metadata = []
        self.query_cache = {}
        self.db_path = f"./data/{name}/vector_db.pkl"

    def load_data(self, data):
        if self.embeddings and self.metadata:
            print("Vector database is already loaded. Skipping data loading.")
            return
        if os.path.exists(self.db_path):
            print("Loading vector database from disk.")
            self.load_db()
            return

        texts = [f"Heading: {item['chunk_heading']}\n\n Chunk Text: {item['text']}" for item in data]
        self._embed_and_store(texts, data)
        self.save_db()
        print("Vector database loaded and saved.")

    def _embed_and_store(self, texts, data):
        batch_size = 128
        result = []

        for i in range(0, len(texts), batch_size):
            response = openai.Embedding.create(
                input=texts[i: i + batch_size],
                model="text-embedding-ada-002"  # Modelo recomendado para embeddings
            )
            embeddings = [res['embedding'] for res in response['data']]
            result.extend(embeddings)

        self.embeddings = result
        self.metadata = data

    def search(self, query, k=5, similarity_threshold=0.75):
        if query in self.query_cache:
            query_embedding = self.query_cache[query]
        else:
            response = openai.Embedding.create(
                input=[query],
                model="text-embedding-ada-002"
            )
            query_embedding = response['data'][0]['embedding']
            self.query_cache[query] = query_embedding

        if not self.embeddings:
            raise ValueError("No data loaded in the vector database.")

        # Cálculo da similaridade utilizando produto escalar
        similarities = np.dot(self.embeddings, query_embedding)
        top_indices = np.argsort(similarities)[::-1]
        top_examples = []

        for idx in top_indices:
            if similarities[idx] >= similarity_threshold:
                example = {
                    "metadata": self.metadata[idx],
                    "similarity": similarities[idx],
                }
                top_examples.append(example)

                if len(top_examples) >= k:
                    break
        self.save_db()
        return top_examples

    def save_db(self):
        data = {
            "embeddings": self.embeddings,
            "metadata": self.metadata,
            "query_cache": json.dumps(self.query_cache),
        }
        os.makedirs(os.path.dirname(self.db_path), exist_ok=True)
        with open(self.db_path, "wb") as file:
            pickle.dump(data, file)

    def load_db(self):
        if not os.path.exists(self.db_path):
            raise ValueError("Vector database file not found. Use load_data to create a new database.")
        with open(self.db_path, "rb") as file:
            data = pickle.load(file)
        self.embeddings = data["embeddings"]
        self.metadata = data["metadata"]
        self.query_cache = json.loads(data["query_cache"])

# %% [markdown]
# # Basic RAG

# %%
from hugchat import hugchat
from hugchat.login import Login
import time
import json

# Configurações de login
EMAIL = "hdsdosol@gmail.com"
PASSWD = "Lisa2210@"
cookie_path_dir = "./cookies/"  # O diretório onde os cookies serão salvos

# Login no HuggingFace
sign = Login(EMAIL, PASSWD)
cookies = sign.login(cookie_dir_path=cookie_path_dir, save_cookies=True)

# Cria o ChatBot com cookies obtidos
chatbot = hugchat.ChatBot(cookies=cookies.get_dict())

# Função para chamar o modelo via HuggingChat
def call_huggingchat(prompt, model_name, retries=3, delay=20):
    models = chatbot.get_available_llm_models()
    model_index = next((i for i, m in enumerate(models) if m.id == model_name), None)

    if model_index is not None:
        chatbot.switch_llm(model_index)
        print(f"Modelo '{model_name}' selecionado com sucesso!")
    else:
        raise ValueError(f"Modelo '{model_name}' não encontrado entre os disponíveis.")

    for attempt in range(retries):
        try:
            chatbot.new_conversation(switch_to=True)
            response = chatbot.chat(prompt)
            return response
        except Exception as e:
            print(f"Erro na tentativa {attempt + 1}: {e}")
            if "You are sending too many messages" in str(e):
                time.sleep(delay)
            else:
                break

    return None

# Carregar o documento do seu caminho específico
with open('/home/lisamenezes/RAG-benchmark/data/fundamentos-train.json', 'r') as f:
    fundamentos_data = json.load(f)

# Inicializar o VectorDB com seus dados
db = VectorDB("fundamentos")
db.load_data(fundamentos_data)

def retrieve_base(query, db):
    results = db.search(query, k=3)
    context = ""
    for result in results:
        chunk = result['metadata']
        context += f"\n{chunk['text']}\n"
    return results, context

def answer_query_base(query, db):
    documents, context = retrieve_base(query, db)
    prompt = f"""
    Você é um assistente juridico que responde a seguinte pergunta: 
    <pergunta>
    {query}
    </pergunta>
    Você tem acesso aos seguintes documentos, que devem fornecer contexto à medida que responde à consulta:
    <contexto>
    {context}
    </contexto>
    Por favor, permaneça fiel ao contexto subjacente e só se desvie dele se tiver 100% de certeza de que já sabe a resposta. 
    Responda à pergunta agora e evite fornecer preâmbulos como 'Aqui está a resposta', etc.
    """
    
    response = call_huggingchat(prompt, model_name="meta-llama/Meta-Llama-3.1-70B-Instruct")
    return response

# %%
# Exemplo de uso para realizar uma consulta e gerar uma resposta
query = "posse provisória"
results, context = retrieve_base(query, db)

print("Contexto Recuperado:")
print(context)

# Gerar o texto usando o LLM
response = answer_query_base(query, db)

print("\nTexto Gerado pelo LLM:")
print(response)
# Out:
# Contexto Recuperado:
#
# Art. 4oSão incapazes,
# 		relativamente a certos atos ou à maneira de os exercer:(Redação dada pela Lei nº 13.146, de
# 2015)(Vigência) I - os maiores de dezesseis e menores de dezoito anos; II - os ébrios habituais e os viciados em
# 		tóxico;(Redação dada pela Lei nº 13.146, de
# 2015)(Vigência) III - aqueles que, por causa transitória ou
# 		permanente, não puderem exprimir sua vontade;(Redação dada pela Lei nº 13.146, de
# 2015)(Vigência) IV - os pródigos. Parágrafo único.  A capacidade dos indígenas
# 		será regulada por legislação especial.(Redação dada pela Lei nº 13.146, de
# 2015)(Vigência)
#
# Art. 3oSão absolutamente
# 		incapazes de exercer pessoalmente os atos da vida civil os menores de 16
# 		(dezesseis) anos.(Redação
# 		dada pela Lei nº 13.146, de
# 2015)(Vigência)
#
# Art. 3oSão absolutamente
# 		incapazes de exercer pessoalmente os atos da vida civil os menores de 16
# 		(dezesseis) anos.(Redação
# 		dada pela Lei nº 13.146, de
# 2015)(Vigência)
#
# Modelo 'meta-llama/Meta-Llama-3.1-70B-Instruct' selecionado com sucesso!
#
# Texto Gerado pelo LLM:
# Traceback (most recent call last):
#   File "/home/lisamenezes/anaconda3/envs/basic/lib/python3.9/site-packages/hugchat/hugchat.py", line 721, in _stream_query
#     for line in resp.iter_lines(decode_unicode=True):
#   File "/home/lisamenezes/anaconda3/envs/basic/lib/python3.9/site-packages/requests/models.py", line 869, in iter_lines
#     for chunk in self.iter_content(
#   File "/home/lisamenezes/anaconda3/envs/basic/lib/python3.9/site-packages/requests/utils.py", line 572, in stream_decode_response_unicode
#     for chunk in iterator:
#   File "/home/lisamenezes/anaconda3/envs/basic/lib/python3.9/site-packages/requests/models.py", line 820, in generate
#     yield from self.raw.stream(chunk_size, decode_content=True)
#   File "/home/lisamenezes/anaconda3/envs/basic/lib/python3.9/site-packages/urllib3/response.py", line 624, in stream
#     for line in self.read_chunked(amt, decode_content=decode_content):
#   File "/home/lisamenezes/anaconda3/envs/basic/lib/python3.9/site-packages/urllib3/response.py", line 828, in read_chunked
#     self._update_chunk_length()
#   File "/home/lisamenezes/anaconda3/envs/basic/lib/python3.9/site-packages/urllib3/response.py", line 758, in _update_chunk_length
#     line = self._fp.fp.readline()
#   File "/home/lisamenezes/anaconda3/envs/basic/lib/python3.9/socket.py", line 704, in readinto
#     return self._sock.recv_into(b)
#   File "/home/lisamenezes/anaconda3/envs/basic/lib/python3.9/ssl.py", line 1275, in recv_into
#     return self.read(nbytes, buffer)
#   File "/home/lisamenezes/anaconda3/envs/basic/lib/python3.9/ssl.py", line 1133, in read
#     return self._sslobj.read(len, buffer)
# KeyboardInterrupt
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# File ~/anaconda3/envs/basic/lib/python3.9/site-packages/hugchat/hugchat.py:721, in ChatBot._stream_query(self, text, web_search, is_retry, retry_count, conversation, message_id)
#     720 try:
# --> 721     for line in resp.iter_lines(decode_unicode=True):
#     722         if not line:
#
# File ~/anaconda3/envs/basic/lib/python3.9/site-packages/requests/models.py:869, in Response.iter_lines(self, chunk_size, decode_unicode, delimiter)
#     867 pending = None
# --> 869 for chunk in self.iter_content(
#     870     chunk_size=chunk_size, decode_unicode=decode_unicode
#     871 ):
#     872     if pending is not None:
#
# File ~/anaconda3/envs/basic/lib/python3.9/site-packages/requests/utils.py:572, in stream_decode_response_unicode(iterator, r)
#     571 decoder = codecs.getincrementaldecoder(r.encoding)(errors="replace")
# --> 572 for chunk in iterator:
#     573     rv = decoder.decode(chunk)
#
# File ~/anaconda3/envs/basic/lib/python3.9/site-packages/requests/models.py:820, in Response.iter_content.<locals>.generate()
#     819 try:
# --> 820     yield from self.raw.stream(chunk_size, decode_content=True)
#     821 except ProtocolError as e:
#
# File ~/anaconda3/envs/basic/lib/python3.9/site-packages/urllib3/response.py:624, in HTTPResponse.stream(self, amt, decode_content)
#     623 if self.chunked and self.supports_chunked_reads():
# --> 624     for line in self.read_chunked(amt, decode_content=decode_content):
#     625         yield line
#
# File ~/anaconda3/envs/basic/lib/python3.9/site-packages/urllib3/response.py:828, in HTTPResponse.read_chunked(self, amt, decode_content)
#     827 while True:
# --> 828     self._update_chunk_length()
#     829     if self.chunk_left == 0:
#
# File ~/anaconda3/envs/basic/lib/python3.9/site-packages/urllib3/response.py:758, in HTTPResponse._update_chunk_length(self)
#     757     return
# --> 758 line = self._fp.fp.readline()
#     759 line = line.split(b";", 1)[0]
#
# File ~/anaconda3/envs/basic/lib/python3.9/socket.py:704, in SocketIO.readinto(self, b)
#     703 try:
# --> 704     return self._sock.recv_into(b)
#     705 except timeout:
#
# File ~/anaconda3/envs/basic/lib/python3.9/ssl.py:1275, in SSLSocket.recv_into(self, buffer, nbytes, flags)
#    1272         raise ValueError(
#    1273           "non-zero flags not allowed in calls to recv_into() on %s" %
#    1274           self.__class__)
# -> 1275     return self.read(nbytes, buffer)
#    1276 else:
#
# File ~/anaconda3/envs/basic/lib/python3.9/ssl.py:1133, in SSLSocket.read(self, len, buffer)
#    1132 if buffer is not None:
# -> 1133     return self._sslobj.read(len, buffer)
#    1134 else:
#
# KeyboardInterrupt:
#
# During handling of the above exception, another exception occurred:
#
# ChatError                                 Traceback (most recent call last)
# Cell In[6], line 12
#       9 response = answer_query_base(query, db)
#      11 print("\nTexto Gerado pelo LLM:")
# ---> 12 print(response)
#
# File ~/anaconda3/envs/basic/lib/python3.9/site-packages/hugchat/message.py:292, in Message.__str__(self)
#     291 def __str__(self):
# --> 292     return self.wait_until_done()
#
# File ~/anaconda3/envs/basic/lib/python3.9/site-packages/hugchat/message.py:259, in Message.wait_until_done(self)
#     252 """
#     253 :Return:
#     254     - self.text if resolved else raise error
#     255
#     256 wait until every response is resolved
#     257 """
#     258 while not self.is_done():
# --> 259     self.__next__()
#     261 if self.is_done() == MessageStatus.RESOLVED:
#     262     return self._result_text
#
# File ~/anaconda3/envs/basic/lib/python3.9/site-packages/hugchat/message.py:200, in Message.__next__(self)
#     198 self.error = e
#     199 self.msg_status = MessageStatus.REJECTED
# --> 200 raise self.error
#
# File ~/anaconda3/envs/basic/lib/python3.9/site-packages/hugchat/message.py:123, in Message.__next__(self)
#     120         raise Exception("Message status is `Rejected` but no error found")
#     122 try:
# --> 123     data: dict = next(self.gen)
#     124     self._filterResponse(data)
#     125     data_type: str = data["type"]
#
# File ~/anaconda3/envs/basic/lib/python3.9/site-packages/hugchat/hugchat.py:747, in ChatBot._stream_query(self, text, web_search, is_retry, retry_count, conversation, message_id)
#     745     if "Conversation not found" in str(res):
#     746         raise exceptions.InvalidConversationIDError("Conversation id invalid")
# --> 747     raise exceptions.ChatError(f"Failed to parse response: {res}")
#     748 if break_flag:
#     749     break
#
# ChatError: Failed to parse response: {"type":"stream","token":"idade\u0000\u0000\u0000\u0000\u0000\u0000\u0000\u0000\u0000\u0000\u0000"}

# %% [markdown]
# # Validação

# %%
import time

def evaluate_model(test_data, db):
    results = []
    total_time = 0
    correct_answers = 0

    for item in test_data:
        query = item['chunk_heading']
        expected_text = item['text']

        # Medir tempo de inferência
        start_time = time.time()
        retrieved_docs, context = retrieve_base(query, db)
        end_time = time.time()

        # Comparar o texto recuperado com o esperado
        is_correct = expected_text.strip() in context.strip()

        # Atualizar métricas
        total_time += (end_time - start_time)
        correct_answers += int(is_correct)

        # Registrar resultados
        results.append({
            "query": query,
            "retrieved_context": context,
            "expected_text": expected_text,
            "is_correct": is_correct,
            "inference_time": end_time - start_time
        })

    # Calcular métricas gerais
    accuracy = correct_answers / len(test_data)
    average_time = total_time / len(test_data)

    return {
        "results": results,
        "accuracy": accuracy,
        "average_inference_time": average_time
    }

# Carregar os dados de teste
with open('/home/lisamenezes/RAG-benchmark/data/fundamentos-test.json', 'r') as f:
    test_data = json.load(f)

# Executar a avaliação
evaluation_results = evaluate_model(test_data, db)

# Exibir os resultados
print(f"Acurácia: {evaluation_results['accuracy'] * 100:.2f}%")
print(f"Tempo médio de inferência: {evaluation_results['average_inference_time']:.2f}s")
# Out:
# Acurácia: 7.20%
# Tempo médio de inferência: 0.30s

# %%
evaluation_results
# Out:
# {'results': [{'query': 'capacidade civil',
#    'retrieved_context': '\nArt. 1oToda pessoa é capaz de direitos e deveres na ordem civil.\n\nArt. 3oSão absolutamente \n\t\tincapazes de exercer pessoalmente os atos da vida civil os menores de 16 \n\t\t(dezesseis) anos.(Redação \n\t\tdada pela Lei nº 13.146, de \n2015)(Vigência)\n\nArt. 4oSão incapazes, \n\t\trelativamente a certos atos ou à maneira de os exercer:(Redação dada pela Lei nº 13.146, de \n2015)(Vigência) I - os maiores de dezesseis e menores de dezoito anos; II - os ébrios habituais e os viciados em \n\t\ttóxico;(Redação dada pela Lei nº 13.146, de \n2015)(Vigência) III - aqueles que, por causa transitória ou \n\t\tpermanente, não puderem exprimir sua vontade;(Redação dada pela Lei nº 13.146, de \n2015)(Vigência) IV - os pródigos. Parágrafo único. \xa0A capacidade dos indígenas \n\t\tserá regulada por legislação especial.(Redação dada pela Lei nº 13.146, de \n2015)(Vigência)\n',
#    'expected_text': 'Art. 1oToda pessoa é capaz de direitos e deveres na ordem civil.',
#    'is_correct': True,
#    'inference_time': 0.2532162666320801},
#   {'query': 'direitos e deveres',
#    'retrieved_context': '\nArt. 1oToda pessoa é capaz de direitos e deveres na ordem civil.\n\nArt. 1oToda pessoa é capaz de direitos e deveres na ordem civil.\n\nArt. 1oToda pessoa é capaz de direitos e deveres na ordem civil.\n',
#    'expected_text': 'Art. 1oToda pessoa é capaz de direitos e deveres na ordem civil.',
#    'is_correct': True,
#    'inference_time': 0.23541760444641113},
#   {'query': 'sujeito de direito',
#    'retrieved_context': '\nArt. 1oToda pessoa é capaz de direitos e deveres na ordem civil.\n\nArt. 1oToda pessoa é capaz de direitos e deveres na ordem civil.\n\nArt. 1oToda pessoa é capaz de direitos e deveres na ordem civil.\n',
#    'expected_text': 'Art. 1oToda pessoa é capaz de direitos e deveres na ordem civil.',
#    'is_correct': True,
#    'inference_time': 0.24509215354919434},
#   {'query': 'nascimento com vida',
#    'retrieved_context': '\nArt. 2oA personalidade civil da pessoa começa do nascimento com\nvida; mas a lei põe a salvo, desde a concepção, os direitos do nascituro.\n\nArt. 2oA personalidade civil da pessoa começa do nascimento com\nvida; mas a lei põe a salvo, desde a concepção, os direitos do nascituro.\n\nArt. 2oA personalidade civil da pessoa começa do nascimento com\nvida; mas a lei põe a salvo, desde a concepção, os direitos do nascituro.\n',
#    'expected_text': 'Art. 2oA personalidade civil da pessoa começa do nascimento com\nvida; mas a lei põe a salvo, desde a concepção, os direitos do nascituro.',
#    'is_correct': True,
#    'inference_time': 0.26185059547424316},
#   {'query': 'direitos do nascituro',
#    'retrieved_context': '\nArt. 2oA personalidade civil da pessoa começa do nascimento com\nvida; mas a lei põe a salvo, desde a concepção, os direitos do nascituro.\n\nArt. 2oA personalidade civil da pessoa começa do nascimento com\nvida; mas a lei põe a salvo, desde a concepção, os direitos do nascituro.\n\nArt. 2oA personalidade civil da pessoa começa do nascimento com\nvida; mas a lei põe a salvo, desde a concepção, os direitos do nascituro.\n',
#    'expected_text': 'Art. 2oA personalidade civil da pessoa começa do nascimento com\nvida; mas a lei põe a salvo, desde a concepção, os direitos do nascituro.',
#    'is_correct': True,
#    'inference_time': 0.25478172302246094},
#   {'query': 'personalidade civil',
#    'retrieved_context': '\nArt. 2oA personalidade civil da pessoa começa do nascimento com\nvida; mas a lei põe a salvo, desde a concepção, os direitos do nascituro.\n\nArt. 1oToda pessoa é capaz de direitos e deveres na ordem civil.\n\nArt. 2oA personalidade civil da pessoa começa do nascimento com\nvida; mas a lei põe a salvo, desde a concepção, os direitos do nascituro.\n',
#    'expected_text': 'Art. 2oA personalidade civil da pessoa começa do nascimento com\nvida; mas a lei põe a salvo, desde a concepção, os direitos do nascituro.',
#    'is_correct': True,
#    'inference_time': 0.2370138168334961},
#   {'query': 'menor de 16 anos',
#    'retrieved_context': '\nArt. 3oSão absolutamente \n\t\tincapazes de exercer pessoalmente os atos da vida civil os menores de 16 \n\t\t(dezesseis) anos.(Redação \n\t\tdada pela Lei nº 13.146, de \n2015)(Vigência)\n\nArt. 3oSão absolutamente \n\t\tincapazes de exercer pessoalmente os atos da vida civil os menores de 16 \n\t\t(dezesseis) anos.(Redação \n\t\tdada pela Lei nº 13.146, de \n2015)(Vigência)\n\nArt. 3oSão absolutamente \n\t\tincapazes de exercer pessoalmente os atos da vida civil os menores de 16 \n\t\t(dezesseis) anos.(Redação \n\t\tdada pela Lei nº 13.146, de \n2015)(Vigência)\n',
#    'expected_text': 'Art. 3oSão absolutamente \n\t\tincapazes de exercer pessoalmente os atos da vida civil os menores de 16 \n\t\t(dezesseis) anos.(Redação \n\t\tdada pela Lei nº 13.146, de \n2015)(Vigência)',
#    'is_correct': True,
#    'inference_time': 0.25200843811035156},
#   {'query': 'incapaz civil',
#    'retrieved_context': '\nArt. 3oSão absolutamente \n\t\tincapazes de exercer pessoalmente os atos da vida civil os menores de 16 \n\t\t(dezesseis) anos.(Redação \n\t\tdada pela Lei nº 13.146, de \n2015)(Vigência)\n\nArt. 1oToda pessoa é capaz de direitos e deveres na ordem civil.\n\nArt. 3oSão absolutamente \n\t\tincapazes de exercer pessoalmente os atos da vida civil os menores de 16 \n\t\t(dezesseis) anos.(Redação \n\t\tdada pela Lei nº 13.146, de \n2015)(Vigência)\n',
#    'expected_text': 'Art. 3oSão absolutamente \n\t\tincapazes de exercer pessoalmente os atos da vida civil os menores de 16 \n\t\t(dezesseis) anos.(Redação \n\t\tdada pela Lei nº 13.146, de \n2015)(Vigência)',
#    'is_correct': True,
#    'inference_time': 0.2411198616027832},
#   {'query': 'incapacidade absoluta',
#    'retrieved_context': '\nArt. 3oSão absolutamente \n\t\tincapazes de exercer pessoalmente os atos da vida civil os menores de 16 \n\t\t(dezesseis) anos.(Redação \n\t\tdada pela Lei nº 13.146, de \n2015)(Vigência)\n\nArt. 4oSão incapazes, \n\t\trelativamente a certos atos ou à maneira de os exercer:(Redação dada pela Lei nº 13.146, de \n2015)(Vigência) I - os maiores de dezesseis e menores de dezoito anos; II - os ébrios habituais e os viciados em \n\t\ttóxico;(Redação dada pela Lei nº 13.146, de \n2015)(Vigência) III - aqueles que, por causa transitória ou \n\t\tpermanente, não puderem exprimir sua vontade;(Redação dada pela Lei nº 13.146, de \n2015)(Vigência) IV - os pródigos. Parágrafo único. \xa0A capacidade dos indígenas \n\t\tserá regulada por legislação especial.(Redação dada pela Lei nº 13.146, de \n2015)(Vigência)\n\nArt. 3oSão absolutamente \n\t\tincapazes de exercer pessoalmente os atos da vida civil os menores de 16 \n\t\t(dezesseis) anos.(Redação \n\t\tdada pela Lei nº 13.146, de \n2015)(Vigência)\n',
#    'expected_text': 'Art. 3oSão absolutamente \n\t\tincapazes de exercer pessoalmente os atos da vida civil os menores de 16 \n\t\t(dezesseis) anos.(Redação \n\t\tdada pela Lei nº 13.146, de \n2015)(Vigência)',
#    'is_correct': True,
#    'inference_time': 0.23090791702270508},
#   {'query': 'incapacidade relativa',
#    'retrieved_context': '\nArt. 4oSão incapazes, \n\t\trelativamente a certos atos ou à maneira de os exercer:(Redação dada pela Lei nº 13.146, de \n2015)(Vigência) I - os maiores de dezesseis e menores de dezoito anos; II - os ébrios habituais e os viciados em \n\t\ttóxico;(Redação dada pela Lei nº 13.146, de \n2015)(Vigência) III - aqueles que, por causa transitória ou \n\t\tpermanente, não puderem exprimir sua vontade;(Redação dada pela Lei nº 13.146, de \n2015)(Vigência) IV - os pródigos. Parágrafo único. \xa0A capacidade dos indígenas \n\t\tserá regulada por legislação especial.(Redação dada pela Lei nº 13.146, de \n2015)(Vigência)\n\nArt. 3oSão absolutamente \n\t\tincapazes de exercer pessoalmente os atos da vida civil os menores de 16 \n\t\t(dezesseis) anos.(Redação \n\t\tdada pela Lei nº 13.146, de \n2015)(Vigência)\n\nArt. 3oSão absolutamente \n\t\tincapazes de exercer pessoalmente os atos da vida civil os menores de 16 \n\t\t(dezesseis) anos.(Redação \n\t\tdada pela Lei nº 13.146, de \n2015)(Vigência)\n',
#    'expected_text': 'Art. 4oSão incapazes, \n\t\trelativamente a certos atos ou à maneira de os exercer:(Redação dada pela Lei nº 13.146, de \n2015)(Vigência) I - os maiores de dezesseis e menores de dezoito anos; II - os ébrios habituais e os viciados em \n\t\ttóxico;(Redação dada pela Lei nº 13.146, de \n2015)(Vigência) III - aqueles que, por causa transitória ou \n\t\tpermanente, não puderem exprimir sua vontade;(Redação dada pela Lei nº 13.146, de \n2015)(Vigência) IV - os pródigos. Parágrafo único. A capacidade dos indígenas \n\t\tserá regulada por legislação especial.(Redação dada pela Lei nº 13.146, de \n2015)(Vigência)',
#    'is_correct': False,
#    'inference_time': 0.24001002311706543},
#   {'query': 'menor de idade',
#    'retrieved_context': '\nArt. 3oSão absolutamente \n\t\tincapazes de exercer pessoalmente os atos da vida civil os menores de 16 \n\t\t(dezesseis) anos.(Redação \n\t\tdada pela Lei nº 13.146, de \n2015)(Vigência)\n\nArt. 3oSão absolutamente \n\t\tincapazes de exercer pessoalmente os atos da vida civil os menores de 16 \n\t\t(dezesseis) anos.(Redação \n\t\tdada pela Lei nº 13.146, de \n2015)(Vigência)\n\nArt. 3oSão absolutamente \n\t\tincapazes de exercer pessoalmente os atos da vida civil os menores de 16 \n\t\t(dezesseis) anos.(Redação \n\t\tdada pela Lei nº 13.146, de \n2015)(Vigência)\n',
#    'expected_text': 'Art. 4oSão incapazes, \n\t\trelativamente a certos atos ou à maneira de os exercer:(Redação dada pela Lei nº 13.146, de \n2015)(Vigência) I - os maiores de dezesseis e menores de dezoito anos; II - os ébrios habituais e os viciados em \n\t\ttóxico;(Redação dada pela Lei nº 13.146, de \n2015)(Vigência) III - aqueles que, por causa transitória ou \n\t\tpermanente, não puderem exprimir sua vontade;(Redação dada pela Lei nº 13.146, de \n2015)(Vigência) IV - os pródigos. Parágrafo único.A capacidade dos indígenas \n\t\tserá regulada por legislação especial.(Redação dada pela Lei nº 13.146, de \n2015)(Vigência)',
#    'is_correct': False,
#    'inference_time': 0.24474549293518066},
#   {'query': 'ébrio habitual',
#    'retrieved_context': '\nArt. 4oSão incapazes, \n\t\trelativamente a certos atos ou à maneira de os exercer:(Redação dada pela Lei nº 13.146, de \n2015)(Vigência) I - os maiores de dezesseis e menores de dezoito anos; II - os ébrios habituais e os viciados em \n\t\ttóxico;(Redação dada pela Lei nº 13.146, de \n2015)(Vigência) III - aqueles que, por causa transitória ou \n\t\tpermanente, não puderem exprimir sua vontade;(Redação dada pela Lei nº 13.146, de \n2015)(Vigência) IV - os pródigos. Parágrafo único. \xa0A capacidade dos indígenas \n\t\tserá regulada por legislação especial.(Redação dada pela Lei nº 13.146, de \n2015)(Vigência)\n\nArt. 3oSão absolutamente \n\t\tincapazes de exercer pessoalmente os atos da vida civil os menores de 16 \n\t\t(dezesseis) anos.(Redação \n\t\tdada pela Lei nº 13.146, de \n2015)(Vigência)\n\nArt. 3oSão absolutamente \n\t\tincapazes de exercer pessoalmente os atos da vida civil os menores de 16 \n\t\t(dezesseis) anos.(Redação \n\t\tdada pela Lei nº 13.146, de \n2015)(Vigência)\n',
#    'expected_text': 'Art. 4oSão incapazes, \n\t\trelativamente a certos atos ou à maneira de os exercer:(Redação dada pela Lei nº 13.146, de \n2015)(Vigência) I - os maiores de dezesseis e menores de dezoito anos; II - os ébrios habituais e os viciados em \n\t\ttóxico;(Redação dada pela Lei nº 13.146, de \n2015)(Vigência) III - aqueles que, por causa transitória ou \n\t\tpermanente, não puderem exprimir sua vontade;(Redação dada pela Lei nº 13.146, de \n2015)(Vigência) IV - os pródigos. Parágrafo único. A capacidade dos indígenas \n\t\tserá regulada por legislação especial.(Redação dada pela Lei nº 13.146, de \n2015)(Vigência)',
#    'is_correct': False,
#    'inference_time': 0.2483363151550293},
#   {'query': 'viciado em tóxico',
#    'retrieved_context': '\nArt. 4oSão incapazes, \n\t\trelativamente a certos atos ou à maneira de os exercer:(Redação dada pela Lei nº 13.146, de \n2015)(Vigência) I - os maiores de dezesseis e menores de dezoito anos; II - os ébrios habituais e os viciados em \n\t\ttóxico;(Redação dada pela Lei nº 13.146, de \n2015)(Vigência) III - aqueles que, por causa transitória ou \n\t\tpermanente, não puderem exprimir sua vontade;(Redação dada pela Lei nº 13.146, de \n2015)(Vigência) IV - os pródigos. Parágrafo único. \xa0A capacidade dos indígenas \n\t\tserá regulada por legislação especial.(Redação dada pela Lei nº 13.146, de \n2015)(Vigência)\n\nArt. 3oSão absolutamente \n\t\tincapazes de exercer pessoalmente os atos da vida civil os menores de 16 \n\t\t(dezesseis) anos.(Redação \n\t\tdada pela Lei nº 13.146, de \n2015)(Vigência)\n\nArt. 3oSão absolutamente \n\t\tincapazes de exercer pessoalmente os atos da vida civil os menores de 16 \n\t\t(dezesseis) anos.(Redação \n\t\tdada pela Lei nº 13.146, de \n2015)(Vigência)\n',
#    'expected_text': 'Art. 4oSão incapazes, \n\t\trelativamente a certos atos ou à maneira de os exercer:(Redação dada pela Lei nº 13.146, de \n2015)(Vigência) I - os maiores de dezesseis e menores de dezoito anos; II - os ébrios habituais e os viciados em \n\t\ttóxico;(Redação dada pela Lei nº 13.146, de \n2015)(Vigência) III - aqueles que, por causa transitória ou \n\t\tpermanente, não puderem exprimir sua vontade;(Redação dada pela Lei nº 13.146, de \n2015)(Vigência) IV - os pródigos. Parágrafo único. A capacidade dos indígenas \n\t\tserá regulada por legislação especial.(Redação dada pela Lei nº 13.146, de \n2015)(Vigência)',
#    'is_correct': False,
#    'inference_time': 0.26157140731811523},
#   {'query': 'incapaz de exprimir vontade',
#    'retrieved_context': '\nArt. 4oSão incapazes, \n\t\trelativamente a certos atos ou à maneira de os exercer:(Redação dada pela Lei nº 13.146, de \n2015)(Vigência) I - os maiores de dezesseis e menores de dezoito anos; II - os ébrios habituais e os viciados em \n\t\ttóxico;(Redação dada pela Lei nº 13.146, de \n2015)(Vigência) III - aqueles que, por causa transitória ou \n\t\tpermanente, não puderem exprimir sua vontade;(Redação dada pela Lei nº 13.146, de \n2015)(Vigência) IV - os pródigos. Parágrafo único. \xa0A capacidade dos indígenas \n\t\tserá regulada por legislação especial.(Redação dada pela Lei nº 13.146, de \n2015)(Vigência)\n\nArt. 3oSão absolutamente \n\t\tincapazes de exercer pessoalmente os atos da vida civil os menores de 16 \n\t\t(dezesseis) anos.(Redação \n\t\tdada pela Lei nº 13.146, de \n2015)(Vigência)\n\nArt. 3oSão absolutamente \n\t\tincapazes de exercer pessoalmente os atos da vida civil os menores de 16 \n\t\t(dezesseis) anos.(Redação \n\t\tdada pela Lei nº 13.146, de \n2015)(Vigência)\n',
#    'expected_text': 'Art. 4oSão incapazes, \n\t\trelativamente a certos atos ou à maneira de os exercer:(Redação dada pela Lei nº 13.146, de \n2015)(Vigência) I - os maiores de dezesseis e menores de dezoito anos; II - os ébrios habituais e os viciados em \n\t\ttóxico;(Redação dada pela Lei nº 13.146, de \n2015)(Vigência) III - aqueles que, por causa transitória ou \n\t\tpermanente, não puderem exprimir sua vontade;(Redação dada pela Lei nº 13.146, de \n2015)(Vigência) IV - os pródigos. Parágrafo único. A capacidade dos indígenas \n\t\tserá regulada por legislação especial.(Redação dada pela Lei nº 13.146, de \n2015)(Vigência)',
#    'is_correct': False,
#    'inference_time': 0.25558996200561523},
#   {'query': 'pródigo',
#    'retrieved_context': '\nArt. 1oToda pessoa é capaz de direitos e deveres na ordem civil.\n\nArt. 1oToda pessoa é capaz de direitos e deveres na ordem civil.\n\nArt. 1oToda pessoa é capaz de direitos e deveres na ordem civil.\n',
#    'expected_text': 'Art. 4oSão incapazes, \n\t\trelativamente a certos atos ou à maneira de os exercer:(Redação dada pela Lei nº 13.146, de \n2015)(Vigência) I - os maiores de dezesseis e menores de dezoito anos; II - os ébrios habituais e os viciados em \n\t\ttóxico;(Redação dada pela Lei nº 13.146, de \n2015)(Vigência) III - aqueles que, por causa transitória ou \n\t\tpermanente, não puderem exprimir sua vontade;(Redação dada pela Lei nº 13.146, de \n2015)(Vigência) IV - os pródigos. Parágrafo único. A capacidade dos indígenas \n\t\tserá regulada por legislação especial.(Redação dada pela Lei nº 13.146, de \n2015)(Vigência)',
#    'is_correct': False,
#    'inference_time': 0.24553394317626953},
#   {'query': 'capacidade indígena',
#    'retrieved_context': '\nArt. 4oSão incapazes, \n\t\trelativamente a certos atos ou à maneira de os exercer:(Redação dada pela Lei nº 13.146, de \n2015)(Vigência) I - os maiores de dezesseis e menores de dezoito anos; II - os ébrios habituais e os viciados em \n\t\ttóxico;(Redação dada pela Lei nº 13.146, de \n2015)(Vigência) III - aqueles que, por causa transitória ou \n\t\tpermanente, não puderem exprimir sua vontade;(Redação dada pela Lei nº 13.146, de \n2015)(Vigência) IV - os pródigos. Parágrafo único. \xa0A capacidade dos indígenas \n\t\tserá regulada por legislação especial.(Redação dada pela Lei nº 13.146, de \n2015)(Vigência)\n\nArt. 1oToda pessoa é capaz de direitos e deveres na ordem civil.\n\nArt. 3oSão absolutamente \n\t\tincapazes de exercer pessoalmente os atos da vida civil os menores de 16 \n\t\t(dezesseis) anos.(Redação \n\t\tdada pela Lei nº 13.146, de \n2015)(Vigência)\n',
#    'expected_text': 'Art. 4oSão incapazes, \n\t\trelativamente a certos atos ou à maneira de os exercer:(Redação dada pela Lei nº 13.146, de \n2015)(Vigência) I - os maiores de dezesseis e menores de dezoito anos; II - os ébrios habituais e os viciados em \n\t\ttóxico;(Redação dada pela Lei nº 13.146, de \n2015)(Vigência) III - aqueles que, por causa transitória ou \n\t\tpermanente, não puderem exprimir sua vontade;(Redação dada pela Lei nº 13.146, de \n2015)(Vigência) IV - os pródigos. Parágrafo único.A capacidade dos indígenas \n\t\tserá regulada por legislação especial.(Redação dada pela Lei nº 13.146, de \n2015)(Vigência)',
#    'is_correct': False,
#    'inference_time': 0.24071907997131348},
#   {'query': 'legislação indígena.',
#    'retrieved_context': '\nArt. 4oSão incapazes, \n\t\trelativamente a certos atos ou à maneira de os exercer:(Redação dada pela Lei nº 13.146, de \n2015)(Vigência) I - os maiores de dezesseis e menores de dezoito anos; II - os ébrios habituais e os viciados em \n\t\ttóxico;(Redação dada pela Lei nº 13.146, de \n2015)(Vigência) III - aqueles que, por causa transitória ou \n\t\tpermanente, não puderem exprimir sua vontade;(Redação dada pela Lei nº 13.146, de \n2015)(Vigência) IV - os pródigos. Parágrafo único. \xa0A capacidade dos indígenas \n\t\tserá regulada por legislação especial.(Redação dada pela Lei nº 13.146, de \n2015)(Vigência)\n\nArt. 1oToda pessoa é capaz de direitos e deveres na ordem civil.\n\nArt. 1oToda pessoa é capaz de direitos e deveres na ordem civil.\n',
#    'expected_text': 'Art. 4oSão incapazes, \n\t\trelativamente a certos atos ou à maneira de os exercer:(Redação dada pela Lei nº 13.146, de \n2015)(Vigência) I - os maiores de dezesseis e menores de dezoito anos; II - os ébrios habituais e os viciados em \n\t\ttóxico;(Redação dada pela Lei nº 13.146, de \n2015)(Vigência) III - aqueles que, por causa transitória ou \n\t\tpermanente, não puderem exprimir sua vontade;(Redação dada pela Lei nº 13.146, de \n2015)(Vigência) IV - os pródigos. Parágrafo único. A capacidade dos indígenas \n\t\tserá regulada por legislação especial.(Redação dada pela Lei nº 13.146, de \n2015)(Vigência)',
#    'is_correct': False,
#    'inference_time': 0.2501037120819092},
#   {'query': 'menoridade',
#    'retrieved_context': '\nArt. 3oSão absolutamente \n\t\tincapazes de exercer pessoalmente os atos da vida civil os menores de 16 \n\t\t(dezesseis) anos.(Redação \n\t\tdada pela Lei nº 13.146, de \n2015)(Vigência)\n\nArt. 3oSão absolutamente \n\t\tincapazes de exercer pessoalmente os atos da vida civil os menores de 16 \n\t\t(dezesseis) anos.(Redação \n\t\tdada pela Lei nº 13.146, de \n2015)(Vigência)\n\nArt. 4oSão incapazes, \n\t\trelativamente a certos atos ou à maneira de os exercer:(Redação dada pela Lei nº 13.146, de \n2015)(Vigência) I - os maiores de dezesseis e menores de dezoito anos; II - os ébrios habituais e os viciados em \n\t\ttóxico;(Redação dada pela Lei nº 13.146, de \n2015)(Vigência) III - aqueles que, por causa transitória ou \n\t\tpermanente, não puderem exprimir sua vontade;(Redação dada pela Lei nº 13.146, de \n2015)(Vigência) IV - os pródigos. Parágrafo único. \xa0A capacidade dos indígenas \n\t\tserá regulada por legislação especial.(Redação dada pela Lei nº 13.146, de \n2015)(Vigência)\n',
#    'expected_text': 'Art. 5oA menoridade cessa aos dezoito anos completos, quando a\npessoa fica habilitada à prática de todos os atos da vida civil. Parágrafo único. Cessará, para os menores, a incapacidade: I - pela concessão dos pais, ou de um deles na falta do outro, mediante instrumento\npúblico, independentemente de homologação judicial, ou por sentença do juiz, ouvido o\ntutor, se o menor tiver dezesseis anos completos; II - pelo casamento; III - pelo exercício de emprego público efetivo; IV - pela colação de grau em curso de ensino superior; V - pelo estabelecimento civil ou comercial, ou pela existência de relação de\nemprego, desde que, em função deles, o menor com dezesseis anos completos tenha economia\nprópria.',
#    'is_correct': False,
#    'inference_time': 0.24655985832214355},
#   {'query': 'idade mínima',
#    'retrieved_context': '\nArt. 3oSão absolutamente \n\t\tincapazes de exercer pessoalmente os atos da vida civil os menores de 16 \n\t\t(dezesseis) anos.(Redação \n\t\tdada pela Lei nº 13.146, de \n2015)(Vigência)\n\nArt. 3oSão absolutamente \n\t\tincapazes de exercer pessoalmente os atos da vida civil os menores de 16 \n\t\t(dezesseis) anos.(Redação \n\t\tdada pela Lei nº 13.146, de \n2015)(Vigência)\n\nArt. 3oSão absolutamente \n\t\tincapazes de exercer pessoalmente os atos da vida civil os menores de 16 \n\t\t(dezesseis) anos.(Redação \n\t\tdada pela Lei nº 13.146, de \n2015)(Vigência)\n',
#    'expected_text': 'Art. 5oA menoridade cessa aos dezoito anos completos, quando a\npessoa fica habilitada à prática de todos os atos da vida civil. Parágrafo único. Cessará, para os menores, a incapacidade: I - pela concessão dos pais, ou de um deles na falta do outro, mediante instrumento\npúblico, independentemente de homologação judicial, ou por sentença do juiz, ouvido o\ntutor, se o menor tiver dezesseis anos completos; II - pelo casamento; III - pelo exercício de emprego público efetivo; IV - pela colação de grau em curso de ensino superior; V - pelo estabelecimento civil ou comercial, ou pela existência de relação de\nemprego, desde que, em função deles, o menor com dezesseis anos completos tenha economia\nprópria.',
#    'is_correct': False,
#    'inference_time': 0.23281288146972656},
#   {'query': 'capacidade civil',
#    'retrieved_context': '\nArt. 1oToda pessoa é capaz de direitos e deveres na ordem civil.\n\nArt. 3oSão absolutamente \n\t\tincapazes de exercer pessoalmente os atos da vida civil os menores de 16 \n\t\t(dezesseis) anos.(Redação \n\t\tdada pela Lei nº 13.146, de \n2015)(Vigência)\n\nArt. 4oSão incapazes, \n\t\trelativamente a certos atos ou à maneira de os exercer:(Redação dada pela Lei nº 13.146, de \n2015)(Vigência) I - os maiores de dezesseis e menores de dezoito anos; II - os ébrios habituais e os viciados em \n\t\ttóxico;(Redação dada pela Lei nº 13.146, de \n2015)(Vigência) III - aqueles que, por causa transitória ou \n\t\tpermanente, não puderem exprimir sua vontade;(Redação dada pela Lei nº 13.146, de \n2015)(Vigência) IV - os pródigos. Parágrafo único. \xa0A capacidade dos indígenas \n\t\tserá regulada por legislação especial.(Redação dada pela Lei nº 13.146, de \n2015)(Vigência)\n',
#    'expected_text': 'Art. 5oA menoridade cessa aos dezoito anos completos, quando a\npessoa fica habilitada à prática de todos os atos da vida civil. Parágrafo único. Cessará, para os menores, a incapacidade: I - pela concessão dos pais, ou de um deles na falta do outro, mediante instrumento\npúblico, independentemente de homologação judicial, ou por sentença do juiz, ouvido o\ntutor, se o menor tiver dezesseis anos completos; II - pelo casamento; III - pelo exercício de emprego público efetivo; IV - pela colação de grau em curso de ensino superior; V - pelo estabelecimento civil ou comercial, ou pela existência de relação de\nemprego, desde que, em função deles, o menor com dezesseis anos completos tenha economia\nprópria.',
#    'is_correct': False,
#    'inference_time': 0.23011088371276855},
#   {'query': 'emancipação',
#    'retrieved_context': '\nArt. 4oSão incapazes, \n\t\trelativamente a certos atos ou à maneira de os exercer:(Redação dada pela Lei nº 13.146, de \n2015)(Vigência) I - os maiores de dezesseis e menores de dezoito anos; II - os ébrios habituais e os viciados em \n\t\ttóxico;(Redação dada pela Lei nº 13.146, de \n2015)(Vigência) III - aqueles que, por causa transitória ou \n\t\tpermanente, não puderem exprimir sua vontade;(Redação dada pela Lei nº 13.146, de \n2015)(Vigência) IV - os pródigos. Parágrafo único. \xa0A capacidade dos indígenas \n\t\tserá regulada por legislação especial.(Redação dada pela Lei nº 13.146, de \n2015)(Vigência)\n\nArt. 1oToda pessoa é capaz de direitos e deveres na ordem civil.\n\nArt. 2oA personalidade civil da pessoa começa do nascimento com\nvida; mas a lei põe a salvo, desde a concepção, os direitos do nascituro.\n',
#    'expected_text': 'Art. 5oA menoridade cessa aos dezoito anos completos, quando a\npessoa fica habilitada à prática de todos os atos da vida civil. Parágrafo único. Cessará, para os menores, a incapacidade: I - pela concessão dos pais, ou de um deles na falta do outro, mediante instrumento\npúblico, independentemente de homologação judicial, ou por sentença do juiz, ouvido o\ntutor, se o menor tiver dezesseis anos completos; II - pelo casamento; III - pelo exercício de emprego público efetivo; IV - pela colação de grau em curso de ensino superior; V - pelo estabelecimento civil ou comercial, ou pela existência de relação de\nemprego, desde que, em função deles, o menor com dezesseis anos completos tenha economia\nprópria.',
#    'is_correct': False,
#    'inference_time': 0.23714709281921387},
#   {'query': 'maioridade',
#    'retrieved_context': '\nArt. 3oSão absolutamente \n\t\tincapazes de exercer pessoalmente os atos da vida civil os menores de 16 \n\t\t(dezesseis) anos.(Redação \n\t\tdada pela Lei nº 13.146, de \n2015)(Vigência)\n\nArt. 3oSão absolutamente \n\t\tincapazes de exercer pessoalmente os atos da vida civil os menores de 16 \n\t\t(dezesseis) anos.(Redação \n\t\tdada pela Lei nº 13.146, de \n2015)(Vigência)\n\nArt. 4oSão incapazes, \n\t\trelativamente a certos atos ou à maneira de os exercer:(Redação dada pela Lei nº 13.146, de \n2015)(Vigência) I - os maiores de dezesseis e menores de dezoito anos; II - os ébrios habituais e os viciados em \n\t\ttóxico;(Redação dada pela Lei nº 13.146, de \n2015)(Vigência) III - aqueles que, por causa transitória ou \n\t\tpermanente, não puderem exprimir sua vontade;(Redação dada pela Lei nº 13.146, de \n2015)(Vigência) IV - os pródigos. Parágrafo único. \xa0A capacidade dos indígenas \n\t\tserá regulada por legislação especial.(Redação dada pela Lei nº 13.146, de \n2015)(Vigência)\n',
#    'expected_text': 'Art. 5oA menoridade cessa aos dezoito anos completos, quando a\npessoa fica habilitada à prática de todos os atos da vida civil. Parágrafo único. Cessará, para os menores, a incapacidade: I - pela concessão dos pais, ou de um deles na falta do outro, mediante instrumento\npúblico, independentemente de homologação judicial, ou por sentença do juiz, ouvido o\ntutor, se o menor tiver dezesseis anos completos; II - pelo casamento; III - pelo exercício de emprego público efetivo; IV - pela colação de grau em curso de ensino superior; V - pelo estabelecimento civil ou comercial, ou pela existência de relação de\nemprego, desde que, em função deles, o menor com dezesseis anos completos tenha economia\nprópria.',
#    'is_correct': False,
#    'inference_time': 0.2411205768585205},
#   {'query': 'ato civil',
#    'retrieved_context': '\nArt. 1oToda pessoa é capaz de direitos e deveres na ordem civil.\n\nArt. 3oSão absolutamente \n\t\tincapazes de exercer pessoalmente os atos da vida civil os menores de 16 \n\t\t(dezesseis) anos.(Redação \n\t\tdada pela Lei nº 13.146, de \n2015)(Vigência)\n\nArt. 3oSão absolutamente \n\t\tincapazes de exercer pessoalmente os atos da vida civil os menores de 16 \n\t\t(dezesseis) anos.(Redação \n\t\tdada pela Lei nº 13.146, de \n2015)(Vigência)\n',
#    'expected_text': 'Art. 5oA menoridade cessa aos dezoito anos completos, quando a\npessoa fica habilitada à prática de todos os atos da vida civil. Parágrafo único. Cessará, para os menores, a incapacidade: I - pela concessão dos pais, ou de um deles na falta do outro, mediante instrumento\npúblico, independentemente de homologação judicial, ou por sentença do juiz, ouvido o\ntutor, se o menor tiver dezesseis anos completos; II - pelo casamento; III - pelo exercício de emprego público efetivo; IV - pela colação de grau em curso de ensino superior; V - pelo estabelecimento civil ou comercial, ou pela existência de relação de\nemprego, desde que, em função deles, o menor com dezesseis anos completos tenha economia\nprópria.',
#    'is_correct': False,
#    'inference_time': 0.25760817527770996},
#   {'query': 'incapacidade',
#    'retrieved_context': '\nArt. 4oSão incapazes, \n\t\trelativamente a certos atos ou à maneira de os exercer:(Redação dada pela Lei nº 13.146, de \n2015)(Vigência) I - os maiores de dezesseis e menores de dezoito anos; II - os ébrios habituais e os viciados em \n\t\ttóxico;(Redação dada pela Lei nº 13.146, de \n2015)(Vigência) III - aqueles que, por causa transitória ou \n\t\tpermanente, não puderem exprimir sua vontade;(Redação dada pela Lei nº 13.146, de \n2015)(Vigência) IV - os pródigos. Parágrafo único. \xa0A capacidade dos indígenas \n\t\tserá regulada por legislação especial.(Redação dada pela Lei nº 13.146, de \n2015)(Vigência)\n\nArt. 3oSão absolutamente \n\t\tincapazes de exercer pessoalmente os atos da vida civil os menores de 16 \n\t\t(dezesseis) anos.(Redação \n\t\tdada pela Lei nº 13.146, de \n2015)(Vigência)\n\nArt. 3oSão absolutamente \n\t\tincapazes de exercer pessoalmente os atos da vida civil os menores de 16 \n\t\t(dezesseis) anos.(Redação \n\t\tdada pela Lei nº 13.146, de \n2015)(Vigência)\n',
#    'expected_text': 'Art. 5oA menoridade cessa aos dezoito anos completos, quando a\npessoa fica habilitada à prática de todos os atos da vida civil. Parágrafo único. Cessará, para os menores, a incapacidade: I - pela concessão dos pais, ou de um deles na falta do outro, mediante instrumento\npúblico, independentemente de homologação judicial, ou por sentença do juiz, ouvido o\ntutor, se o menor tiver dezesseis anos completos; II - pelo casamento; III - pelo exercício de emprego público efetivo; IV - pela colação de grau em curso de ensino superior; V - pelo estabelecimento civil ou comercial, ou pela existência de relação de\nemprego, desde que, em função deles, o menor com dezesseis anos completos tenha economia\nprópria.',
#    'is_correct': False,
#    'inference_time': 0.24121308326721191},
#   {'query': 'cessação',
#    'retrieved_context': '\nArt. 4oSão incapazes, \n\t\trelativamente a certos atos ou à maneira de os exercer:(Redação dada pela Lei nº 13.146, de \n2015)(Vigência) I - os maiores de dezesseis e menores de dezoito anos; II - os ébrios habituais e os viciados em \n\t\ttóxico;(Redação dada pela Lei nº 13.146, de \n2015)(Vigência) III - aqueles que, por causa transitória ou \n\t\tpermanente, não puderem exprimir sua vontade;(Redação dada pela Lei nº 13.146, de \n2015)(Vigência) IV - os pródigos. Parágrafo único. \xa0A capacidade dos indígenas \n\t\tserá regulada por legislação especial.(Redação dada pela Lei nº 13.146, de \n2015)(Vigência)\n\nArt. 3oSão absolutamente \n\t\tincapazes de exercer pessoalmente os atos da vida civil os menores de 16 \n\t\t(dezesseis) anos.(Redação \n\t\tdada pela Lei nº 13.146, de \n2015)(Vigência)\n\nArt. 3oSão absolutamente \n\t\tincapazes de exercer pessoalmente os atos da vida civil os menores de 16 \n\t\t(dezesseis) anos.(Redação \n\t\tdada pela Lei nº 13.146, de \n2015)(Vigência)\n',
#    'expected_text': 'Art. 5oA menoridade cessa aos dezoito anos completos, quando a\npessoa fica habilitada à prática de todos os atos da vida civil. Parágrafo único. Cessará, para os menores, a incapacidade: I - pela concessão dos pais, ou de um deles na falta do outro, mediante instrumento\npúblico, independentemente de homologação judicial, ou por sentença do juiz, ouvido o\ntutor, se o menor tiver dezesseis anos completos; II - pelo casamento; III - pelo exercício de emprego público efetivo; IV - pela colação de grau em curso de ensino superior; V - pelo estabelecimento civil ou comercial, ou pela existência de relação de\nemprego, desde que, em função deles, o menor com dezesseis anos completos tenha economia\nprópria.',
#    'is_correct': False,
#    'inference_time': 0.23597502708435059},
#   {'query': 'menor de 18 anos.',
#    'retrieved_context': '\nArt. 3oSão absolutamente \n\t\tincapazes de exercer pessoalmente os atos da vida civil os menores de 16 \n\t\t(dezesseis) anos.(Redação \n\t\tdada pela Lei nº 13.146, de \n2015)(Vigência)\n\nArt. 3oSão absolutamente \n\t\tincapazes de exercer pessoalmente os atos da vida civil os menores de 16 \n\t\t(dezesseis) anos.(Redação \n\t\tdada pela Lei nº 13.146, de \n2015)(Vigência)\n\nArt. 3oSão absolutamente \n\t\tincapazes de exercer pessoalmente os atos da vida civil os menores de 16 \n\t\t(dezesseis) anos.(Redação \n\t\tdada pela Lei nº 13.146, de \n2015)(Vigência)\n',
#    'expected_text': 'Art. 5oA menoridade cessa aos dezoito anos completos, quando a\npessoa fica habilitada à prática de todos os atos da vida civil. Parágrafo único. Cessará, para os menores, a incapacidade: I - pela concessão dos pais, ou de um deles na falta do outro, mediante instrumento\npúblico, independentemente de homologação judicial, ou por sentença do juiz, ouvido o\ntutor, se o menor tiver dezesseis anos completos; II - pelo casamento; III - pelo exercício de emprego público efetivo; IV - pela colação de grau em curso de ensino superior; V - pelo estabelecimento civil ou comercial, ou pela existência de relação de\nemprego, desde que, em função deles, o menor com dezesseis anos completos tenha economia\nprópria.',
#    'is_correct': False,
#    'inference_time': 0.23399925231933594},
#   {'query': 'morte',
#    'retrieved_context': '\nArt. 4oSão incapazes, \n\t\trelativamente a certos atos ou à maneira de os exercer:(Redação dada pela Lei nº 13.146, de \n2015)(Vigência) I - os maiores de dezesseis e menores de dezoito anos; II - os ébrios habituais e os viciados em \n\t\ttóxico;(Redação dada pela Lei nº 13.146, de \n2015)(Vigência) III - aqueles que, por causa transitória ou \n\t\tpermanente, não puderem exprimir sua vontade;(Redação dada pela Lei nº 13.146, de \n2015)(Vigência) IV - os pródigos. Parágrafo único. \xa0A capacidade dos indígenas \n\t\tserá regulada por legislação especial.(Redação dada pela Lei nº 13.146, de \n2015)(Vigência)\n\nArt. 3oSão absolutamente \n\t\tincapazes de exercer pessoalmente os atos da vida civil os menores de 16 \n\t\t(dezesseis) anos.(Redação \n\t\tdada pela Lei nº 13.146, de \n2015)(Vigência)\n\nArt. 2oA personalidade civil da pessoa começa do nascimento com\nvida; mas a lei põe a salvo, desde a concepção, os direitos do nascituro.\n',
#    'expected_text': 'Art. 6oA existência da pessoa natural termina com a morte;\npresume-se esta, quanto aos ausentes, nos casos em que a lei autoriza a abertura de\nsucessão definitiva.',
#    'is_correct': False,
#    'inference_time': 0.24671602249145508},
#   {'query': 'ausente',
#    'retrieved_context': '\nArt. 3oSão absolutamente \n\t\tincapazes de exercer pessoalmente os atos da vida civil os menores de 16 \n\t\t(dezesseis) anos.(Redação \n\t\tdada pela Lei nº 13.146, de \n2015)(Vigência)\n\nArt. 3oSão absolutamente \n\t\tincapazes de exercer pessoalmente os atos da vida civil os menores de 16 \n\t\t(dezesseis) anos.(Redação \n\t\tdada pela Lei nº 13.146, de \n2015)(Vigência)\n\nArt. 4oSão incapazes, \n\t\trelativamente a certos atos ou à maneira de os exercer:(Redação dada pela Lei nº 13.146, de \n2015)(Vigência) I - os maiores de dezesseis e menores de dezoito anos; II - os ébrios habituais e os viciados em \n\t\ttóxico;(Redação dada pela Lei nº 13.146, de \n2015)(Vigência) III - aqueles que, por causa transitória ou \n\t\tpermanente, não puderem exprimir sua vontade;(Redação dada pela Lei nº 13.146, de \n2015)(Vigência) IV - os pródigos. Parágrafo único. \xa0A capacidade dos indígenas \n\t\tserá regulada por legislação especial.(Redação dada pela Lei nº 13.146, de \n2015)(Vigência)\n',
#    'expected_text': 'Art. 6oA existência da pessoa natural termina com a morte;\npresume-se esta, quanto aos ausentes, nos casos em que a lei autoriza a abertura de\nsucessão definitiva.',
#    'is_correct': False,
#    'inference_time': 0.23961710929870605},
#   {'query': 'sucessão definitiva',
#    'retrieved_context': '\nArt. 3oSão absolutamente \n\t\tincapazes de exercer pessoalmente os atos da vida civil os menores de 16 \n\t\t(dezesseis) anos.(Redação \n\t\tdada pela Lei nº 13.146, de \n2015)(Vigência)\n\nArt. 4oSão incapazes, \n\t\trelativamente a certos atos ou à maneira de os exercer:(Redação dada pela Lei nº 13.146, de \n2015)(Vigência) I - os maiores de dezesseis e menores de dezoito anos; II - os ébrios habituais e os viciados em \n\t\ttóxico;(Redação dada pela Lei nº 13.146, de \n2015)(Vigência) III - aqueles que, por causa transitória ou \n\t\tpermanente, não puderem exprimir sua vontade;(Redação dada pela Lei nº 13.146, de \n2015)(Vigência) IV - os pródigos. Parágrafo único. \xa0A capacidade dos indígenas \n\t\tserá regulada por legislação especial.(Redação dada pela Lei nº 13.146, de \n2015)(Vigência)\n\nArt. 1oToda pessoa é capaz de direitos e deveres na ordem civil.\n',
#    'expected_text': 'Art. 6oA existência da pessoa natural termina com a morte;\npresume-se esta, quanto aos ausentes, nos casos em que a lei autoriza a abertura de\nsucessão definitiva.',
#    'is_correct': False,
#    'inference_time': 0.24303054809570312},
#   {'query': 'morte presumida',
#    'retrieved_context': '\nArt. 3oSão absolutamente \n\t\tincapazes de exercer pessoalmente os atos da vida civil os menores de 16 \n\t\t(dezesseis) anos.(Redação \n\t\tdada pela Lei nº 13.146, de \n2015)(Vigência)\n\nArt. 4oSão incapazes, \n\t\trelativamente a certos atos ou à maneira de os exercer:(Redação dada pela Lei nº 13.146, de \n2015)(Vigência) I - os maiores de dezesseis e menores de dezoito anos; II - os ébrios habituais e os viciados em \n\t\ttóxico;(Redação dada pela Lei nº 13.146, de \n2015)(Vigência) III - aqueles que, por causa transitória ou \n\t\tpermanente, não puderem exprimir sua vontade;(Redação dada pela Lei nº 13.146, de \n2015)(Vigência) IV - os pródigos. Parágrafo único. \xa0A capacidade dos indígenas \n\t\tserá regulada por legislação especial.(Redação dada pela Lei nº 13.146, de \n2015)(Vigência)\n\nArt. 3oSão absolutamente \n\t\tincapazes de exercer pessoalmente os atos da vida civil os menores de 16 \n\t\t(dezesseis) anos.(Redação \n\t\tdada pela Lei nº 13.146, de \n2015)(Vigência)\n',
#    'expected_text': 'Art. 7oPode ser declarada a morte presumida, sem decretação de\nausência: I - se for extremamente provável a morte de quem estava em perigo de vida; II - se alguém, desaparecido em campanha ou feito prisioneiro, não for encontrado\naté dois anos após o término da guerra. Parágrafo único. A declaração da morte presumida, nesses casos, somente poderá ser\nrequerida depois de esgotadas as buscas e averiguações, devendo a sentença fixar a data\nprovável do falecimento.',
#    'is_correct': False,
#    'inference_time': 0.2435929775238037},
#   {'query': 'declaração de morte presumida',
#    'retrieved_context': '\nArt. 3oSão absolutamente \n\t\tincapazes de exercer pessoalmente os atos da vida civil os menores de 16 \n\t\t(dezesseis) anos.(Redação \n\t\tdada pela Lei nº 13.146, de \n2015)(Vigência)\n\nArt. 4oSão incapazes, \n\t\trelativamente a certos atos ou à maneira de os exercer:(Redação dada pela Lei nº 13.146, de \n2015)(Vigência) I - os maiores de dezesseis e menores de dezoito anos; II - os ébrios habituais e os viciados em \n\t\ttóxico;(Redação dada pela Lei nº 13.146, de \n2015)(Vigência) III - aqueles que, por causa transitória ou \n\t\tpermanente, não puderem exprimir sua vontade;(Redação dada pela Lei nº 13.146, de \n2015)(Vigência) IV - os pródigos. Parágrafo único. \xa0A capacidade dos indígenas \n\t\tserá regulada por legislação especial.(Redação dada pela Lei nº 13.146, de \n2015)(Vigência)\n\nArt. 2oA personalidade civil da pessoa começa do nascimento com\nvida; mas a lei põe a salvo, desde a concepção, os direitos do nascituro.\n',
#    'expected_text': 'Art. 7oPode ser declarada a morte presumida, sem decretação de\nausência: I - se for extremamente provável a morte de quem estava em perigo de vida; II - se alguém, desaparecido em campanha ou feito prisioneiro, não for encontrado\naté dois anos após o término da guerra. Parágrafo único. A declaração da morte presumida, nesses casos, somente poderá ser\nrequerida depois de esgotadas as buscas e averiguações, devendo a sentença fixar a data\nprovável do falecimento.',
#    'is_correct': False,
#    'inference_time': 0.24912428855895996},
#   {'query': 'desaparecimento em campanha',
#    'retrieved_context': '\nArt. 3oSão absolutamente \n\t\tincapazes de exercer pessoalmente os atos da vida civil os menores de 16 \n\t\t(dezesseis) anos.(Redação \n\t\tdada pela Lei nº 13.146, de \n2015)(Vigência)\n\nArt. 3oSão absolutamente \n\t\tincapazes de exercer pessoalmente os atos da vida civil os menores de 16 \n\t\t(dezesseis) anos.(Redação \n\t\tdada pela Lei nº 13.146, de \n2015)(Vigência)\n\nArt. 4oSão incapazes, \n\t\trelativamente a certos atos ou à maneira de os exercer:(Redação dada pela Lei nº 13.146, de \n2015)(Vigência) I - os maiores de dezesseis e menores de dezoito anos; II - os ébrios habituais e os viciados em \n\t\ttóxico;(Redação dada pela Lei nº 13.146, de \n2015)(Vigência) III - aqueles que, por causa transitória ou \n\t\tpermanente, não puderem exprimir sua vontade;(Redação dada pela Lei nº 13.146, de \n2015)(Vigência) IV - os pródigos. Parágrafo único. \xa0A capacidade dos indígenas \n\t\tserá regulada por legislação especial.(Redação dada pela Lei nº 13.146, de \n2015)(Vigência)\n',
#    'expected_text': 'Art. 7oPode ser declarada a morte presumida, sem decretação de\nausência: I - se for extremamente provável a morte de quem estava em perigo de vida; II - se alguém, desaparecido em campanha ou feito prisioneiro, não for encontrado\naté dois anos após o término da guerra. Parágrafo único. A declaração da morte presumida, nesses casos, somente poderá ser\nrequerida depois de esgotadas as buscas e averiguações, devendo a sentença fixar a data\nprovável do falecimento.',
#    'is_correct': False,
#    'inference_time': 0.23970413208007812},
#   {'query': 'morte simultânea',
#    'retrieved_context': '\nArt. 4oSão incapazes, \n\t\trelativamente a certos atos ou à maneira de os exercer:(Redação dada pela Lei nº 13.146, de \n2015)(Vigência) I - os maiores de dezesseis e menores de dezoito anos; II - os ébrios habituais e os viciados em \n\t\ttóxico;(Redação dada pela Lei nº 13.146, de \n2015)(Vigência) III - aqueles que, por causa transitória ou \n\t\tpermanente, não puderem exprimir sua vontade;(Redação dada pela Lei nº 13.146, de \n2015)(Vigência) IV - os pródigos. Parágrafo único. \xa0A capacidade dos indígenas \n\t\tserá regulada por legislação especial.(Redação dada pela Lei nº 13.146, de \n2015)(Vigência)\n\nArt. 3oSão absolutamente \n\t\tincapazes de exercer pessoalmente os atos da vida civil os menores de 16 \n\t\t(dezesseis) anos.(Redação \n\t\tdada pela Lei nº 13.146, de \n2015)(Vigência)\n\nArt. 2oA personalidade civil da pessoa começa do nascimento com\nvida; mas a lei põe a salvo, desde a concepção, os direitos do nascituro.\n',
#    'expected_text': 'Art. 8oSe dois ou mais indivíduos falecerem na mesma ocasião, não\nse podendo averiguar se algum dos comorientes precedeu aos outros, presumir-se-ão\nsimultaneamente mortos.',
#    'is_correct': False,
#    'inference_time': 0.2422645092010498},
#   {'query': 'presunção de morte simultânea',
#    'retrieved_context': '\nArt. 4oSão incapazes, \n\t\trelativamente a certos atos ou à maneira de os exercer:(Redação dada pela Lei nº 13.146, de \n2015)(Vigência) I - os maiores de dezesseis e menores de dezoito anos; II - os ébrios habituais e os viciados em \n\t\ttóxico;(Redação dada pela Lei nº 13.146, de \n2015)(Vigência) III - aqueles que, por causa transitória ou \n\t\tpermanente, não puderem exprimir sua vontade;(Redação dada pela Lei nº 13.146, de \n2015)(Vigência) IV - os pródigos. Parágrafo único. \xa0A capacidade dos indígenas \n\t\tserá regulada por legislação especial.(Redação dada pela Lei nº 13.146, de \n2015)(Vigência)\n\nArt. 3oSão absolutamente \n\t\tincapazes de exercer pessoalmente os atos da vida civil os menores de 16 \n\t\t(dezesseis) anos.(Redação \n\t\tdada pela Lei nº 13.146, de \n2015)(Vigência)\n\nArt. 2oA personalidade civil da pessoa começa do nascimento com\nvida; mas a lei põe a salvo, desde a concepção, os direitos do nascituro.\n',
#    'expected_text': 'Art. 8oSe dois ou mais indivíduos falecerem na mesma ocasião, não\nse podendo averiguar se algum dos comorientes precedeu aos outros, presumir-se-ão\nsimultaneamente mortos.',
#    'is_correct': False,
#    'inference_time': 0.23135662078857422},
#   {'query': 'falecimento em mesma ocasião',
#    'retrieved_context': '\nArt. 2oA personalidade civil da pessoa começa do nascimento com\nvida; mas a lei põe a salvo, desde a concepção, os direitos do nascituro.\n\nArt. 2oA personalidade civil da pessoa começa do nascimento com\nvida; mas a lei põe a salvo, desde a concepção, os direitos do nascituro.\n\nArt. 3oSão absolutamente \n\t\tincapazes de exercer pessoalmente os atos da vida civil os menores de 16 \n\t\t(dezesseis) anos.(Redação \n\t\tdada pela Lei nº 13.146, de \n2015)(Vigência)\n',
#    'expected_text': 'Art. 8oSe dois ou mais indivíduos falecerem na mesma ocasião, não\nse podendo averiguar se algum dos comorientes precedeu aos outros, presumir-se-ão\nsimultaneamente mortos.',
#    'is_correct': False,
#    'inference_time': 0.23935413360595703},
#   {'query': 'registro de nascimento',
#    'retrieved_context': '\nArt. 2oA personalidade civil da pessoa começa do nascimento com\nvida; mas a lei põe a salvo, desde a concepção, os direitos do nascituro.\n\nArt. 2oA personalidade civil da pessoa começa do nascimento com\nvida; mas a lei põe a salvo, desde a concepção, os direitos do nascituro.\n\nArt. 2oA personalidade civil da pessoa começa do nascimento com\nvida; mas a lei põe a salvo, desde a concepção, os direitos do nascituro.\n',
#    'expected_text': 'Art. 9oSerão registrados em registro público: I - os nascimentos, casamentos e óbitos; II - a emancipação por outorga dos pais ou por sentença do juiz; III - a interdição por incapacidade absoluta ou relativa; IV - a sentença declaratória de ausência e de morte presumida.',
#    'is_correct': False,
#    'inference_time': 0.2355639934539795},
#   {'query': 'registro de casamento',
#    'retrieved_context': '\nArt. 1oToda pessoa é capaz de direitos e deveres na ordem civil.\n\nArt. 3oSão absolutamente \n\t\tincapazes de exercer pessoalmente os atos da vida civil os menores de 16 \n\t\t(dezesseis) anos.(Redação \n\t\tdada pela Lei nº 13.146, de \n2015)(Vigência)\n\nArt. 1oToda pessoa é capaz de direitos e deveres na ordem civil.\n',
# ...
#    'expected_text': 'Art. 29. Antes da partilha, o juiz, quando julgar conveniente, ordenará a conversão\ndos bens móveis, sujeitos a deterioração ou a extravio, em imóveis ou em títulos\ngarantidos pela União.',
#    'is_correct': False,
#    'inference_time': 0.4236271381378174},
#   {'query': 'conversão de bens antes da partilha',
#    'retrieved_context': '\nArt. 4oSão incapazes, \n\t\trelativamente a certos atos ou à maneira de os exercer:(Redação dada pela Lei nº 13.146, de \n2015)(Vigência) I - os maiores de dezesseis e menores de dezoito anos; II - os ébrios habituais e os viciados em \n\t\ttóxico;(Redação dada pela Lei nº 13.146, de \n2015)(Vigência) III - aqueles que, por causa transitória ou \n\t\tpermanente, não puderem exprimir sua vontade;(Redação dada pela Lei nº 13.146, de \n2015)(Vigência) IV - os pródigos. Parágrafo único. \xa0A capacidade dos indígenas \n\t\tserá regulada por legislação especial.(Redação dada pela Lei nº 13.146, de \n2015)(Vigência)\n\nArt. 1oToda pessoa é capaz de direitos e deveres na ordem civil.\n\nArt. 1oToda pessoa é capaz de direitos e deveres na ordem civil.\n',
#    'expected_text': 'Art. 29. Antes da partilha, o juiz, quando julgar conveniente, ordenará a conversão\ndos bens móveis, sujeitos a deterioração ou a extravio, em imóveis ou em títulos\ngarantidos pela União.',
#    'is_correct': False,
#    'inference_time': 0.3818650245666504},
#   {'query': 'posse de bens de ausente',
#    'retrieved_context': '\nArt. 3oSão absolutamente \n\t\tincapazes de exercer pessoalmente os atos da vida civil os menores de 16 \n\t\t(dezesseis) anos.(Redação \n\t\tdada pela Lei nº 13.146, de \n2015)(Vigência)\n\nArt. 4oSão incapazes, \n\t\trelativamente a certos atos ou à maneira de os exercer:(Redação dada pela Lei nº 13.146, de \n2015)(Vigência) I - os maiores de dezesseis e menores de dezoito anos; II - os ébrios habituais e os viciados em \n\t\ttóxico;(Redação dada pela Lei nº 13.146, de \n2015)(Vigência) III - aqueles que, por causa transitória ou \n\t\tpermanente, não puderem exprimir sua vontade;(Redação dada pela Lei nº 13.146, de \n2015)(Vigência) IV - os pródigos. Parágrafo único. \xa0A capacidade dos indígenas \n\t\tserá regulada por legislação especial.(Redação dada pela Lei nº 13.146, de \n2015)(Vigência)\n\nArt. 3oSão absolutamente \n\t\tincapazes de exercer pessoalmente os atos da vida civil os menores de 16 \n\t\t(dezesseis) anos.(Redação \n\t\tdada pela Lei nº 13.146, de \n2015)(Vigência)\n',
#    'expected_text': 'Art. 30. Os herdeiros, para se imitirem na posse dos bens do ausente, darão garantias\nda restituição deles, mediante penhores ou hipotecas equivalentes aos quinhões\nrespectivos.',
#    'is_correct': False,
#    'inference_time': 0.34952783584594727},
#   {'query': 'garantia de restituição de bens',
#    'retrieved_context': '\nArt. 1oToda pessoa é capaz de direitos e deveres na ordem civil.\n\nArt. 1oToda pessoa é capaz de direitos e deveres na ordem civil.\n\nArt. 1oToda pessoa é capaz de direitos e deveres na ordem civil.\n',
#    'expected_text': 'Art. 30. Os herdeiros, para se imitirem na posse dos bens do ausente, darão garantias\nda restituição deles, mediante penhores ou hipotecas equivalentes aos quinhões\nrespectivos.',
#    'is_correct': False,
#    'inference_time': 0.31965088844299316},
#   {'query': 'herdeiros e bens do ausente',
#    'retrieved_context': '\nArt. 3oSão absolutamente \n\t\tincapazes de exercer pessoalmente os atos da vida civil os menores de 16 \n\t\t(dezesseis) anos.(Redação \n\t\tdada pela Lei nº 13.146, de \n2015)(Vigência)\n\nArt. 1oToda pessoa é capaz de direitos e deveres na ordem civil.\n\nArt. 4oSão incapazes, \n\t\trelativamente a certos atos ou à maneira de os exercer:(Redação dada pela Lei nº 13.146, de \n2015)(Vigência) I - os maiores de dezesseis e menores de dezoito anos; II - os ébrios habituais e os viciados em \n\t\ttóxico;(Redação dada pela Lei nº 13.146, de \n2015)(Vigência) III - aqueles que, por causa transitória ou \n\t\tpermanente, não puderem exprimir sua vontade;(Redação dada pela Lei nº 13.146, de \n2015)(Vigência) IV - os pródigos. Parágrafo único. \xa0A capacidade dos indígenas \n\t\tserá regulada por legislação especial.(Redação dada pela Lei nº 13.146, de \n2015)(Vigência)\n',
#    'expected_text': 'Art. 30. Os herdeiros, para se imitirem na posse dos bens do ausente, darão garantias\nda restituição deles, mediante penhores ou hipotecas equivalentes aos quinhões\nrespectivos.',
#    'is_correct': False,
#    'inference_time': 0.3193354606628418},
#   {'query': 'posse provisória',
#    'retrieved_context': '\nArt. 4oSão incapazes, \n\t\trelativamente a certos atos ou à maneira de os exercer:(Redação dada pela Lei nº 13.146, de \n2015)(Vigência) I - os maiores de dezesseis e menores de dezoito anos; II - os ébrios habituais e os viciados em \n\t\ttóxico;(Redação dada pela Lei nº 13.146, de \n2015)(Vigência) III - aqueles que, por causa transitória ou \n\t\tpermanente, não puderem exprimir sua vontade;(Redação dada pela Lei nº 13.146, de \n2015)(Vigência) IV - os pródigos. Parágrafo único. \xa0A capacidade dos indígenas \n\t\tserá regulada por legislação especial.(Redação dada pela Lei nº 13.146, de \n2015)(Vigência)\n\nArt. 3oSão absolutamente \n\t\tincapazes de exercer pessoalmente os atos da vida civil os menores de 16 \n\t\t(dezesseis) anos.(Redação \n\t\tdada pela Lei nº 13.146, de \n2015)(Vigência)\n\nArt. 3oSão absolutamente \n\t\tincapazes de exercer pessoalmente os atos da vida civil os menores de 16 \n\t\t(dezesseis) anos.(Redação \n\t\tdada pela Lei nº 13.146, de \n2015)(Vigência)\n',
#    'expected_text': 'Art. 30 - § 1oAquele que tiver direito à posse provisória, mas não puder\nprestar a garantia exigida neste artigo, será excluído, mantendo-se os bens que lhe\ndeviam caber sob a administração do curador, ou de outro herdeiro designado pelo juiz, e\nque preste essa garantia.',
#    'is_correct': False,
#    'inference_time': 0.3155486583709717},
#   {'query': 'direito à posse provisória',
#    'retrieved_context': '\nArt. 1oToda pessoa é capaz de direitos e deveres na ordem civil.\n\nArt. 4oSão incapazes, \n\t\trelativamente a certos atos ou à maneira de os exercer:(Redação dada pela Lei nº 13.146, de \n2015)(Vigência) I - os maiores de dezesseis e menores de dezoito anos; II - os ébrios habituais e os viciados em \n\t\ttóxico;(Redação dada pela Lei nº 13.146, de \n2015)(Vigência) III - aqueles que, por causa transitória ou \n\t\tpermanente, não puderem exprimir sua vontade;(Redação dada pela Lei nº 13.146, de \n2015)(Vigência) IV - os pródigos. Parágrafo único. \xa0A capacidade dos indígenas \n\t\tserá regulada por legislação especial.(Redação dada pela Lei nº 13.146, de \n2015)(Vigência)\n\nArt. 1oToda pessoa é capaz de direitos e deveres na ordem civil.\n',
#    'expected_text': 'Art. 30 - § 1oAquele que tiver direito à posse provisória, mas não puder\nprestar a garantia exigida neste artigo, será excluído, mantendo-se os bens que lhe\ndeviam caber sob a administração do curador, ou de outro herdeiro designado pelo juiz, e\nque preste essa garantia.',
#    'is_correct': False,
#    'inference_time': 0.3615381717681885},
#   {'query': 'garantia exigida em posse provisória',
#    'retrieved_context': '\nArt. 4oSão incapazes, \n\t\trelativamente a certos atos ou à maneira de os exercer:(Redação dada pela Lei nº 13.146, de \n2015)(Vigência) I - os maiores de dezesseis e menores de dezoito anos; II - os ébrios habituais e os viciados em \n\t\ttóxico;(Redação dada pela Lei nº 13.146, de \n2015)(Vigência) III - aqueles que, por causa transitória ou \n\t\tpermanente, não puderem exprimir sua vontade;(Redação dada pela Lei nº 13.146, de \n2015)(Vigência) IV - os pródigos. Parágrafo único. \xa0A capacidade dos indígenas \n\t\tserá regulada por legislação especial.(Redação dada pela Lei nº 13.146, de \n2015)(Vigência)\n\nArt. 3oSão absolutamente \n\t\tincapazes de exercer pessoalmente os atos da vida civil os menores de 16 \n\t\t(dezesseis) anos.(Redação \n\t\tdada pela Lei nº 13.146, de \n2015)(Vigência)\n\nArt. 1oToda pessoa é capaz de direitos e deveres na ordem civil.\n',
#    'expected_text': 'Art. 30 - § 1oAquele que tiver direito à posse provisória, mas não puder\nprestar a garantia exigida neste artigo, será excluído, mantendo-se os bens que lhe\ndeviam caber sob a administração do curador, ou de outro herdeiro designado pelo juiz, e\nque preste essa garantia.',
#    'is_correct': False,
#    'inference_time': 0.41986083984375},
#   {'query': 'posse de bens do ausente',
#    'retrieved_context': '\nArt. 3oSão absolutamente \n\t\tincapazes de exercer pessoalmente os atos da vida civil os menores de 16 \n\t\t(dezesseis) anos.(Redação \n\t\tdada pela Lei nº 13.146, de \n2015)(Vigência)\n\nArt. 4oSão incapazes, \n\t\trelativamente a certos atos ou à maneira de os exercer:(Redação dada pela Lei nº 13.146, de \n2015)(Vigência) I - os maiores de dezesseis e menores de dezoito anos; II - os ébrios habituais e os viciados em \n\t\ttóxico;(Redação dada pela Lei nº 13.146, de \n2015)(Vigência) III - aqueles que, por causa transitória ou \n\t\tpermanente, não puderem exprimir sua vontade;(Redação dada pela Lei nº 13.146, de \n2015)(Vigência) IV - os pródigos. Parágrafo único. \xa0A capacidade dos indígenas \n\t\tserá regulada por legislação especial.(Redação dada pela Lei nº 13.146, de \n2015)(Vigência)\n\nArt. 3oSão absolutamente \n\t\tincapazes de exercer pessoalmente os atos da vida civil os menores de 16 \n\t\t(dezesseis) anos.(Redação \n\t\tdada pela Lei nº 13.146, de \n2015)(Vigência)\n',
#    'expected_text': 'Art. 30 - § 2oOs ascendentes, os descendentes e o cônjuge, uma vez provada a\nsua qualidade de herdeiros, poderão, independentemente de garantia, entrar na posse dos\nbens do ausente.',
#    'is_correct': False,
#    'inference_time': 0.3921775817871094},
#   {'query': 'herança de ausente',
#    'retrieved_context': '\nArt. 3oSão absolutamente \n\t\tincapazes de exercer pessoalmente os atos da vida civil os menores de 16 \n\t\t(dezesseis) anos.(Redação \n\t\tdada pela Lei nº 13.146, de \n2015)(Vigência)\n\nArt. 4oSão incapazes, \n\t\trelativamente a certos atos ou à maneira de os exercer:(Redação dada pela Lei nº 13.146, de \n2015)(Vigência) I - os maiores de dezesseis e menores de dezoito anos; II - os ébrios habituais e os viciados em \n\t\ttóxico;(Redação dada pela Lei nº 13.146, de \n2015)(Vigência) III - aqueles que, por causa transitória ou \n\t\tpermanente, não puderem exprimir sua vontade;(Redação dada pela Lei nº 13.146, de \n2015)(Vigência) IV - os pródigos. Parágrafo único. \xa0A capacidade dos indígenas \n\t\tserá regulada por legislação especial.(Redação dada pela Lei nº 13.146, de \n2015)(Vigência)\n\nArt. 3oSão absolutamente \n\t\tincapazes de exercer pessoalmente os atos da vida civil os menores de 16 \n\t\t(dezesseis) anos.(Redação \n\t\tdada pela Lei nº 13.146, de \n2015)(Vigência)\n',
#    'expected_text': 'Art. 30 - § 2oOs ascendentes, os descendentes e o cônjuge, uma vez provada a\nsua qualidade de herdeiros, poderão, independentemente de garantia, entrar na posse dos\nbens do ausente.',
#    'is_correct': False,
#    'inference_time': 0.4015083312988281},
#   {'query': 'direitos sucessórios do ausente',
#    'retrieved_context': '\nArt. 1oToda pessoa é capaz de direitos e deveres na ordem civil.\n\nArt. 3oSão absolutamente \n\t\tincapazes de exercer pessoalmente os atos da vida civil os menores de 16 \n\t\t(dezesseis) anos.(Redação \n\t\tdada pela Lei nº 13.146, de \n2015)(Vigência)\n\nArt. 2oA personalidade civil da pessoa começa do nascimento com\nvida; mas a lei põe a salvo, desde a concepção, os direitos do nascituro.\n',
#    'expected_text': 'Art. 30 - § 2oOs ascendentes, os descendentes e o cônjuge, uma vez provada a\nsua qualidade de herdeiros, poderão, independentemente de garantia, entrar na posse dos\nbens do ausente.',
#    'is_correct': False,
#    'inference_time': 0.3446519374847412},
#   {'query': 'alienação de bens de ausente',
#    'retrieved_context': '\nArt. 3oSão absolutamente \n\t\tincapazes de exercer pessoalmente os atos da vida civil os menores de 16 \n\t\t(dezesseis) anos.(Redação \n\t\tdada pela Lei nº 13.146, de \n2015)(Vigência)\n\nArt. 4oSão incapazes, \n\t\trelativamente a certos atos ou à maneira de os exercer:(Redação dada pela Lei nº 13.146, de \n2015)(Vigência) I - os maiores de dezesseis e menores de dezoito anos; II - os ébrios habituais e os viciados em \n\t\ttóxico;(Redação dada pela Lei nº 13.146, de \n2015)(Vigência) III - aqueles que, por causa transitória ou \n\t\tpermanente, não puderem exprimir sua vontade;(Redação dada pela Lei nº 13.146, de \n2015)(Vigência) IV - os pródigos. Parágrafo único. \xa0A capacidade dos indígenas \n\t\tserá regulada por legislação especial.(Redação dada pela Lei nº 13.146, de \n2015)(Vigência)\n\nArt. 3oSão absolutamente \n\t\tincapazes de exercer pessoalmente os atos da vida civil os menores de 16 \n\t\t(dezesseis) anos.(Redação \n\t\tdada pela Lei nº 13.146, de \n2015)(Vigência)\n',
#    'expected_text': 'Art. 31. Os imóveis do ausente só se poderão alienar, não sendo por\ndesapropriação, ou hipotecar, quando o ordene o juiz, para lhes evitar a ruína.',
#    'is_correct': False,
#    'inference_time': 0.3379344940185547},
#   {'query': 'venda de imóvel de ausente',
#    'retrieved_context': '\nArt. 3oSão absolutamente \n\t\tincapazes de exercer pessoalmente os atos da vida civil os menores de 16 \n\t\t(dezesseis) anos.(Redação \n\t\tdada pela Lei nº 13.146, de \n2015)(Vigência)\n\nArt. 3oSão absolutamente \n\t\tincapazes de exercer pessoalmente os atos da vida civil os menores de 16 \n\t\t(dezesseis) anos.(Redação \n\t\tdada pela Lei nº 13.146, de \n2015)(Vigência)\n\nArt. 4oSão incapazes, \n\t\trelativamente a certos atos ou à maneira de os exercer:(Redação dada pela Lei nº 13.146, de \n2015)(Vigência) I - os maiores de dezesseis e menores de dezoito anos; II - os ébrios habituais e os viciados em \n\t\ttóxico;(Redação dada pela Lei nº 13.146, de \n2015)(Vigência) III - aqueles que, por causa transitória ou \n\t\tpermanente, não puderem exprimir sua vontade;(Redação dada pela Lei nº 13.146, de \n2015)(Vigência) IV - os pródigos. Parágrafo único. \xa0A capacidade dos indígenas \n\t\tserá regulada por legislação especial.(Redação dada pela Lei nº 13.146, de \n2015)(Vigência)\n',
#    'expected_text': 'Art. 31. Os imóveis do ausente só se poderão alienar, não sendo por\ndesapropriação, ou hipotecar, quando o ordene o juiz, para lhes evitar a ruína.',
#    'is_correct': False,
#    'inference_time': 0.3329622745513916},
#   {'query': 'hipoteca de imóvel de ausente',
#    'retrieved_context': '\nArt. 3oSão absolutamente \n\t\tincapazes de exercer pessoalmente os atos da vida civil os menores de 16 \n\t\t(dezesseis) anos.(Redação \n\t\tdada pela Lei nº 13.146, de \n2015)(Vigência)\n\nArt. 4oSão incapazes, \n\t\trelativamente a certos atos ou à maneira de os exercer:(Redação dada pela Lei nº 13.146, de \n2015)(Vigência) I - os maiores de dezesseis e menores de dezoito anos; II - os ébrios habituais e os viciados em \n\t\ttóxico;(Redação dada pela Lei nº 13.146, de \n2015)(Vigência) III - aqueles que, por causa transitória ou \n\t\tpermanente, não puderem exprimir sua vontade;(Redação dada pela Lei nº 13.146, de \n2015)(Vigência) IV - os pródigos. Parágrafo único. \xa0A capacidade dos indígenas \n\t\tserá regulada por legislação especial.(Redação dada pela Lei nº 13.146, de \n2015)(Vigência)\n\nArt. 3oSão absolutamente \n\t\tincapazes de exercer pessoalmente os atos da vida civil os menores de 16 \n\t\t(dezesseis) anos.(Redação \n\t\tdada pela Lei nº 13.146, de \n2015)(Vigência)\n',
#    'expected_text': 'Art. 31. Os imóveis do ausente só se poderão alienar, não sendo por\ndesapropriação, ou hipotecar, quando o ordene o juiz, para lhes evitar a ruína.',
#    'is_correct': False,
#    'inference_time': 0.38117265701293945}],
#  'accuracy': 0.072,
#  'average_inference_time': 0.2713555965423584}

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity
import numpy as np

def calculate_similarity(expected_text, retrieved_context):
    # Vetorização usando TF-IDF
    vectorizer = TfidfVectorizer().fit([expected_text, retrieved_context])
    tfidf_matrix = vectorizer.transform([expected_text, retrieved_context])
    
    # Similaridade de cosseno
    similarity = cosine_similarity(tfidf_matrix[0:1], tfidf_matrix[1:2])[0][0]
    return similarity

def evaluate_model_with_similarity(test_data, db, similarity_threshold=0.75):
    results = []
    total_time = 0
    correct_answers = 0

    for item in test_data:
        query = item['chunk_heading']
        expected_text = item['text']

        # Medir tempo de inferência
        start_time = time.time()
        retrieved_docs, context = retrieve_base(query, db)
        end_time = time.time()

        # Calcular a similaridade entre o texto esperado e o contexto recuperado
        similarity = calculate_similarity(expected_text, context)
        is_correct = similarity >= similarity_threshold

        # Atualizar métricas
        total_time += (end_time - start_time)
        correct_answers += int(is_correct)

        # Registrar resultados
        results.append({
            "query": query,
            "retrieved_context": context,
            "expected_text": expected_text,
            "similarity": similarity,
            "is_correct": is_correct,
            "inference_time": end_time - start_time
        })

    # Calcular métricas gerais
    accuracy = correct_answers / len(test_data)
    average_time = total_time / len(test_data)

    return {
        "results": results,
        "accuracy": accuracy,
        "average_inference_time": average_time
    }
# Carregar os dados de teste
with open('/home/lisamenezes/RAG-benchmark/data/fundamentos-test.json', 'r') as f:
    test_data = json.load(f)

# Executar a avaliação
evaluation_results = evaluate_model_with_similarity(test_data, db)

# Exibir os resultados
print(f"Acurácia: {evaluation_results['accuracy'] * 100:.2f}%")
print(f"Tempo médio de inferência: {evaluation_results['average_inference_time']:.2f}s")
# Out:
# Acurácia: 11.20%
# Tempo médio de inferência: 0.31s

# %%
evaluation_results
